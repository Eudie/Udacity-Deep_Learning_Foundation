# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = '../../../Data/For_emmbedding'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('../../../Data/For_emmbedding/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir ../../../Data/For_emmbedding/checkpoints

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "../../../Data/For_emmbedding/checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6571 0.1591 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6218 0.1543 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5008 0.1526 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5781 0.1520 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5248 0.1528 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5256 0.1532 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5498 0.1532 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5436 0.1581 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4662 0.1630 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4641 0.1634 sec/batch
# Nearest to however: guildhall, streptococcus, linker, epidemiological, gershom, shaping, essayist, roget,
# Nearest to into: fredrick, gie, sindhu, buckminster, reus, crimea, fontana, chronicles,
# Nearest to its: decarlo, tastes, gwyneth, warners, massif, donald, aktion, carthusian,
# Nearest to have: robes, filipino, honolulu, buddy, seagal, pds, exceptionalism, fawn,
# Nearest to an: minogue, franchise, glenda, edging, markedly, prague, personages, fly,
# Nearest to many: justly, outkast, purana, soothing, gch, roundheads, mutinies, avail,
# Nearest to been: charted, redirected, baa, jeet, taxonomy, nothing, noblemen, study,
# Nearest to often: printed, thebes, carlsbad, thickness, cretan, waist, cathedral, marginalize,
# Nearest to institute: diamonds, ld, constructor, somers, brno, phalange, aulus, hurley,
# Nearest to shown: ferranti, clearances, bindings, musculus, aretha, embry, ladd, astrometry,
# Nearest to stage: nacional, bavaria, eudes, mpc, shiva, bury, doubts, prefaces,
# Nearest to defense: simulacrum, freedb, requires, cheeses, hopf, disregarded, miniaturized, reassured,
# Nearest to issue: lavandula, zhuyin, participates, hafizullah, bresson, disease, dovich, palmas,
# Nearest to prince: lambeth, umno, minos, ell, obp, dragonfly, godesberg, templi,
# Nearest to dr: handset, ghettos, irritant, bronstein, nn, usp, bambino, behistun,
# Nearest to test: fraggle, gotten, locusts, mammalian, bloated, insulators, browsers, lunatics,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4575 0.1625 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3522 0.1639 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3583 0.1633 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2526 0.1631 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1687 0.1593 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1386 0.1632 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0900 0.1630 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0406 0.1627 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0150 0.1626 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9703 0.1581 sec/batch
# Nearest to however: guildhall, should, dealings, linker, shaping, intensity, streptococcus, plays,
# Nearest to into: gie, empty, restrict, fredrick, premier, tries, chronicles, cbs,
# Nearest to its: donald, gwyneth, hostile, massif, carthusian, tastes, much, decarlo,
# Nearest to have: robes, filipino, many, honolulu, words, pds, movement, televised,
# Nearest to an: franchise, minogue, markedly, temperatures, funk, fly, glenda, prague,
# Nearest to many: justly, have, diversify, nukem, gloria, good, global, roundheads,
# Nearest to been: nothing, study, charted, jeet, fermat, redirected, noblemen, taxonomy,
# Nearest to often: printed, franchise, windsor, waist, thickness, remaining, jersey, cathedral,
# Nearest to institute: diamonds, ld, brno, helps, aulus, somers, constructor, video,
# Nearest to shown: society, approximated, ferranti, depth, productivity, clearances, example, bindings,
# Nearest to stage: nacional, has, prefaces, malaysia, disabilities, bavaria, takeover, invoking,
# Nearest to defense: simulacrum, disregarded, requires, cheeses, hopf, freedb, assemblers, craters,
# Nearest to issue: effective, disease, basis, dismiss, thin, making, hafizullah, participates,
# Nearest to prince: lambeth, umno, ell, minos, dragonfly, godesberg, scenes, tei,
# Nearest to dr: handset, ghettos, cohen, envoys, wikis, vi, determines, livio,
# Nearest to test: gotten, fraggle, locusts, browsers, followings, insulators, waddingtons, mammalian,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9559 0.1665 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9042 0.1630 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8556 0.1595 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8738 0.1601 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8001 0.1550 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8316 0.1522 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8152 0.1514 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7983 0.1597 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7797 0.1604 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7819 0.1617 sec/batch
# Nearest to however: guildhall, linker, streptococcus, should, avoided, dealings, roget, epidemiological,
# Nearest to into: gie, restrict, anna, empty, redistribution, fredrick, buckminster, kepler,
# Nearest to its: tastes, donald, vandalism, faith, massif, gwyneth, incompatible, decarlo,
# Nearest to have: robes, honolulu, filipino, pds, decreases, many, deepened, buddy,
# Nearest to an: franchise, minogue, fly, markedly, funk, glenda, ns, prague,
# Nearest to many: justly, diversify, roundheads, nukem, gloria, fertilizer, purana, avail,
# Nearest to been: nothing, charted, redirected, study, taxonomy, forefront, baa, noblemen,
# Nearest to often: printed, windsor, franchise, cathedral, thickness, doctrines, waist, sizes,
# Nearest to institute: diamonds, ld, helps, brno, somers, aulus, classicists, constructor,
# Nearest to shown: approximated, clearances, ferranti, hate, society, degenerated, depth, embry,
# Nearest to stage: nacional, bavaria, takeover, disabilities, has, shiva, invoking, prefaces,
# Nearest to defense: simulacrum, disregarded, requires, cheeses, hopf, assemblers, mathrm, turned,
# Nearest to issue: dismiss, effective, provisionally, participates, disease, basis, making, thin,
# Nearest to prince: lambeth, umno, ell, minos, dragonfly, scenes, sh, tei,
# Nearest to dr: handset, ghettos, envoys, cohen, wikis, irritant, vi, multiply,
# Nearest to test: gotten, period, actual, browsers, dire, followings, affecting, delay,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7862 0.1616 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7456 0.1600 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7157 0.1619 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7075 0.1610 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7310 0.1616 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6954 0.1683 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7182 0.1608 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7399 0.1585 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7244 0.1530 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6458 0.1507 sec/batch
# Nearest to however: linker, guildhall, streptococcus, should, epidemiological, roget, negatively, gershom,
# Nearest to into: gie, sindhu, redistribution, restrict, anna, empty, kepler, buckminster,
# Nearest to its: vandalism, gwyneth, tastes, decarlo, donald, massif, horrors, arp,
# Nearest to have: honolulu, robes, many, pds, buddy, filipino, decreases, gaelic,
# Nearest to an: minogue, franchise, fly, funk, markedly, glenda, prague, ns,
# Nearest to many: justly, prospects, fertilizer, have, diversify, brighton, purana, nukem,
# Nearest to been: charted, nothing, redirected, glider, study, forefront, taxonomy, noblemen,
# Nearest to often: printed, doctrines, thickness, windsor, parrot, franchise, yukon, waist,
# Nearest to institute: diamonds, ld, helps, somers, brno, constructor, classicists, aulus,
# Nearest to shown: clearances, ferranti, approximated, aretha, bindings, ddd, degenerated, embry,
# Nearest to stage: nacional, bury, bavaria, eudes, shiva, mpc, invoking, disabilities,
# Nearest to defense: simulacrum, disregarded, cheeses, requires, hopf, assemblers, turned, mathrm,
# Nearest to issue: dismiss, participates, provisionally, disease, effective, basis, hopeful, hafizullah,
# Nearest to prince: lambeth, ell, umno, minos, prosper, dragonfly, georg, scenes,
# Nearest to dr: handset, cohen, ghettos, vi, envoys, irritant, vivid, wikis,
# Nearest to test: gotten, fraggle, actual, insulators, affecting, period, delay, visited,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6668 0.1538 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6732 0.1522 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6081 0.1597 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6258 0.1499 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6360 0.1514 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6522 0.1502 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5827 0.1101 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5519 0.1604 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5203 0.1511 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5242 0.1543 sec/batch
# Nearest to however: linker, guildhall, epidemiological, streptococcus, should, stylus, negatively, roget,
# Nearest to into: gie, sindhu, redistribution, buckminster, crimea, fredrick, kepler, statesmen,
# Nearest to its: revoking, arp, vandalism, decarlo, gwyneth, massif, warners, horrors,
# Nearest to have: robes, many, honolulu, decreases, exceptionalism, pds, buddy, anecdotal,
# Nearest to an: minogue, franchise, fly, glenda, markedly, ns, eyeglasses, piet,
# Nearest to many: justly, have, fertilizer, prospects, transwomen, nukem, brighton, diversify,
# Nearest to been: charted, redirected, nothing, glider, forefront, baa, noblemen, temple,
# Nearest to often: printed, doctrines, thickness, waist, mockingly, parrot, accurate, sizes,
# Nearest to institute: ld, diamonds, constructor, classicists, somers, brno, helps, aulus,
# Nearest to shown: clearances, ferranti, approximated, aretha, bindings, depth, ddd, embry,
# Nearest to stage: nacional, bury, westernized, htp, eudes, mpc, vitamin, delmarva,
# Nearest to defense: simulacrum, disregarded, cheeses, assemblers, hopf, requires, tove, mathrm,
# Nearest to issue: dismiss, hopeful, provisionally, participates, disease, effective, hafizullah, basis,
# Nearest to prince: lambeth, ell, umno, minos, prosper, crowned, georg, marvin,
# Nearest to dr: handset, cohen, ghettos, vi, envoys, irritant, wikis, gilgal,
# Nearest to test: gotten, fraggle, insulators, affecting, actual, period, mammalian, delay,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4784 0.1586 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4770 0.1609 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4518 0.1547 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5155 0.1517 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4986 0.1496 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4578 0.1490 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4876 0.1491 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3989 0.1509 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4337 0.1863 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4417 0.1767 sec/batch
# Nearest to however: linker, should, guildhall, streptococcus, negatively, epidemiological, stylus, passageway,
# Nearest to into: sindhu, buckminster, redistribution, gie, reus, polymers, subsidizes, statesmen,
# Nearest to its: revoking, vandalism, arp, warners, decarlo, gwyneth, massif, ulterior,
# Nearest to have: many, honolulu, robes, anecdotal, decreases, malleability, levites, pds,
# Nearest to an: minogue, fly, franchise, markedly, glenda, fabricating, ns, heimskringla,
# Nearest to many: fertilizer, justly, have, prospects, nukem, transwomen, gch, purana,
# Nearest to been: redirected, charted, nothing, glider, forefront, noblemen, temple, taxonomy,
# Nearest to often: printed, doctrines, waist, sizes, mockingly, thickness, accurate, parrot,
# Nearest to institute: diamonds, ld, constructor, classicists, somers, phalange, aulus, mi,
# Nearest to shown: clearances, ferranti, bindings, coyote, approximated, aretha, depth, embry,
# Nearest to stage: westernized, bury, mpc, htp, nacional, vitamin, shiva, delmarva,
# Nearest to defense: simulacrum, disregarded, cheeses, assemblers, requires, hopf, mcdonnell, lancer,
# Nearest to issue: dismiss, hopeful, effective, provisionally, basis, participates, disease, making,
# Nearest to prince: lambeth, ell, umno, minos, prosper, crowned, backer, marvin,
# Nearest to dr: handset, cohen, ghettos, envoys, vi, gilgal, fra, bambino,
# Nearest to test: gotten, fraggle, insulators, affecting, actual, delay, mammalian, browsers,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4190 0.1805 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4319 0.1763 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4521 0.1762 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3996 0.1768 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4267 0.1775 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4484 0.1761 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3525 0.1751 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3857 0.1750 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4067 0.1752 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3904 0.1757 sec/batch
# Nearest to however: linker, guildhall, streptococcus, negatively, stylus, should, epidemiological, passageway,
# Nearest to into: buckminster, sindhu, gie, redistribution, reus, empty, polymers, dvi,
# Nearest to its: revoking, decarlo, warners, vandalism, ulterior, arp, profitability, gwyneth,
# Nearest to have: many, honolulu, robes, seagal, levites, fueling, osu, contend,
# Nearest to an: minogue, fly, ns, horizontally, fabricating, eyeglasses, flow, heimskringla,
# Nearest to many: have, justly, prospects, transwomen, fertilizer, perceived, nukem, gch,
# Nearest to been: charted, redirected, nothing, glider, parvati, forefront, taxonomy, temple,
# Nearest to often: printed, doctrines, waist, ultimate, marginalize, sizes, thickness, qualifies,
# Nearest to institute: ld, diamonds, constructor, classicists, somers, video, magazine, phalange,
# Nearest to shown: ferranti, clearances, bindings, approximated, coyote, aretha, keck, embry,
# Nearest to stage: westernized, bury, htp, mpc, tie, delmarva, nacional, kuznetsova,
# Nearest to defense: disregarded, cheeses, simulacrum, assemblers, freedb, lancer, requires, hopf,
# Nearest to issue: dismiss, hopeful, basis, provisionally, effective, making, participates, quarters,
# Nearest to prince: lambeth, crowned, minos, umno, backer, prosper, ell, namesake,
# Nearest to dr: handset, cohen, ghettos, gilgal, envoys, vi, bronstein, fra,
# Nearest to test: fraggle, insulators, gotten, affecting, delay, browsers, double, actual,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3910 0.1779 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3695 0.1744 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3519 0.1739 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3666 0.1586 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3850 0.1490 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3472 0.1492 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3628 0.1535 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3998 0.1464 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.2937 0.1446 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3301 0.1442 sec/batch
# Nearest to however: linker, negatively, guildhall, epidemiological, streptococcus, should, stylus, crelle,
# Nearest to into: sindhu, displaced, reus, buckminster, modernization, gie, wagon, redistribution,
# Nearest to its: revoking, decarlo, vandalism, warners, ulterior, profitability, local, builds,
# Nearest to have: many, robes, honolulu, seagal, malleability, allege, unicef, fueling,
# Nearest to an: minogue, fly, eyeglasses, xlv, fabricating, wholesalers, ns, piet,
# Nearest to many: have, justly, prospects, transwomen, organisations, perceived, nukem, fertilizer,
# Nearest to been: charted, redirected, nothing, forefront, glider, parvati, temple, taxonomy,
# Nearest to often: printed, doctrines, ultimate, waist, sizes, qualifies, thickness, accurate,
# Nearest to institute: classicists, ld, diamonds, constructor, somers, magazine, stanford, phalange,
# Nearest to shown: ferranti, approximated, clearances, bindings, aretha, coyote, keck, signatory,
# Nearest to stage: westernized, bury, mpc, htp, tie, morten, kuznetsova, microcode,
# Nearest to defense: disregarded, simulacrum, cheeses, requires, freedb, assemblers, batavia, lancer,
# Nearest to issue: dismiss, hopeful, basis, provisionally, effective, making, eliminate, hafizullah,
# Nearest to prince: crowned, lambeth, umno, minos, backer, ell, prosper, battle,
# Nearest to dr: handset, cohen, fra, gilgal, imaginings, bronstein, biographies, spectacle,
# Nearest to test: gotten, insulators, fraggle, affecting, delay, browsers, scratched, spares,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3457 0.1455 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2651 0.1446 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3569 0.1449 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3766 0.1451 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3951 0.1451 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2851 0.1443 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3228 0.1444 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3418 0.1448 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2153 0.1453 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2887 0.1450 sec/batch
# Nearest to however: linker, negatively, epidemiological, ruthenian, streptococcus, stylus, should, guildhall,
# Nearest to into: buckminster, reus, sindhu, gie, displaced, empty, morrie, redistribution,
# Nearest to its: revoking, decarlo, vandalism, warners, ulterior, arp, spo, profitability,
# Nearest to have: many, robes, honolulu, seagal, fueling, allege, malleability, censors,
# Nearest to an: minogue, fly, xlv, ns, motionless, eyeglasses, outranks, ivo,
# Nearest to many: organisations, prospects, have, transwomen, justly, nukem, own, fertilizer,
# Nearest to been: charted, redirected, forefront, parvati, nothing, glider, taxonomy, evacuees,
# Nearest to often: printed, doctrines, ultimate, qualifies, waist, sizes, providing, formulations,
# Nearest to institute: ld, classicists, diamonds, constructor, stanford, phalange, magazine, vocational,
# Nearest to shown: ferranti, clearances, aretha, coyote, approximated, bindings, keck, musculus,
# Nearest to stage: westernized, bury, morten, tie, coffey, htp, mpc, delmarva,
# Nearest to defense: disregarded, simulacrum, cheeses, requires, lancer, freedb, combat, referendum,
# Nearest to issue: dismiss, hopeful, provisionally, basis, effective, hafizullah, making, investigation,
# Nearest to prince: lambeth, crowned, umno, minos, backer, ell, namesake, battle,
# Nearest to dr: handset, cohen, gilgal, biographies, bronstein, fra, imaginings, irritant,
# Nearest to test: gotten, insulators, affecting, fraggle, telco, delay, actual, browsers,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3058 0.1458 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2838 0.1446 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3278 0.0612 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2550 0.1451 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2145 0.1450 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1909 0.1448 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2341 0.1445 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2209 0.1454 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2449 0.1450 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1585 0.1445 sec/batch
# Nearest to however: linker, negatively, streptococcus, passageway, epidemiological, ruthenian, should, crelle,
# Nearest to into: reus, sindhu, buckminster, displaced, gie, modernization, empty, retrieving,
# Nearest to its: revoking, decarlo, vandalism, arp, warners, ulterior, builds, has,
# Nearest to have: many, robes, fueling, ltv, honolulu, unicef, seagal, crunch,
# Nearest to an: minogue, fly, xlv, eyeglasses, motionless, fabricating, outranks, options,
# Nearest to many: organisations, have, prospects, transwomen, nukem, own, brighton, justly,
# Nearest to been: redirected, charted, forefront, nothing, parvati, glider, nerthus, evacuees,
# Nearest to often: printed, doctrines, ultimate, waist, sizes, qualifies, providing, stoppages,
# Nearest to institute: classicists, ld, stanford, diamonds, constructor, phalange, vocational, journals,
# Nearest to shown: ferranti, clearances, aretha, coyote, bindings, keck, approximated, musculus,
# Nearest to stage: westernized, htp, mpc, morten, tie, vitamin, delmarva, cameroons,
# Nearest to defense: disregarded, simulacrum, combat, cheeses, requires, lancer, freedb, trypanosomiasis,
# Nearest to issue: dismiss, hopeful, provisionally, basis, investigation, making, hafizullah, effective,
# Nearest to prince: lambeth, crowned, umno, minos, backer, ell, prosper, castile,
# Nearest to dr: handset, cohen, imaginings, biographies, irritant, gilgal, bronstein, bambino,
# Nearest to test: insulators, gotten, telco, fraggle, delay, affecting, attracts, spares,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2325 0.1458 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2410 0.1445 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2324 0.1445 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1128 0.1444 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1749 0.1455 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1764 0.1447 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1721 0.1444 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1935 0.1444 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2040 0.1446 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1873 0.1441 sec/batch
# Nearest to however: linker, streptococcus, negatively, epidemiological, passageway, stylus, should, ruthenian,
# Nearest to into: reus, sindhu, buckminster, displaced, empty, retrieving, gie, modernization,
# Nearest to its: revoking, decarlo, warners, vandalism, ulterior, incompatible, applications, arp,
# Nearest to have: many, robes, fueling, acceptable, ltv, crunch, honolulu, decreases,
# Nearest to an: minogue, fly, eyeglasses, franchise, glenda, outranks, xlv, fabricating,
# Nearest to many: organisations, have, transwomen, nukem, prospects, fertilizer, firmness, gch,
# Nearest to been: charted, redirected, nothing, parvati, glider, forefront, taxonomy, temple,
# Nearest to often: printed, doctrines, qualifies, ultimate, providing, waist, sizes, stoppages,
# Nearest to institute: classicists, stanford, ld, vocational, institutions, constructor, diamonds, phalange,
# Nearest to shown: clearances, coyote, aretha, approximated, ferranti, keck, bindings, musculus,
# Nearest to stage: westernized, htp, tie, morten, vitamin, mpc, coffey, shiva,
# Nearest to defense: disregarded, simulacrum, combat, cheeses, lancer, freedb, requires, mcdonnell,
# Nearest to issue: dismiss, hopeful, provisionally, basis, eliminate, making, investigation, effective,
# Nearest to prince: lambeth, umno, crowned, minos, ell, prosper, ptolemaic, backer,
# Nearest to dr: handset, imaginings, cohen, irritant, biographies, bronstein, gilgal, krueger,
# Nearest to test: gotten, insulators, delay, telco, fraggle, affecting, spares, scratched,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1920 0.1508 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2229 0.1844 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1666 0.1743 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1577 0.1762 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1790 0.1716 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1852 0.1568 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2032 0.1665 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1743 0.1582 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1358 0.1552 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1803 0.1508 sec/batch
# Nearest to however: linker, passageway, negatively, streptococcus, ruthenian, stylus, epidemiological, commented,
# Nearest to into: reus, gie, empty, buckminster, retrieving, displaced, morrie, sindhu,
# Nearest to its: revoking, decarlo, warners, ulterior, spo, vandalism, applications, has,
# Nearest to have: many, ltv, alphabetization, unicef, acceptable, robes, censors, allege,
# Nearest to an: minogue, fly, outranks, eyeglasses, tude, xlv, fabricating, motionless,
# Nearest to many: have, organisations, transwomen, nukem, prospects, own, some, cults,
# Nearest to been: charted, redirected, forefront, nothing, taxonomy, parvati, glider, nerthus,
# Nearest to often: doctrines, printed, ultimate, stoppages, qualifies, providing, roll, sorceresses,
# Nearest to institute: stanford, classicists, vocational, ld, institutions, faculty, constructor, phalange,
# Nearest to shown: aretha, clearances, coyote, ferranti, keck, approximated, bindings, plano,
# Nearest to stage: westernized, coffey, morten, htp, tie, fringes, archie, portraying,
# Nearest to defense: disregarded, combat, simulacrum, lancer, cheeses, freedb, requires, mcdonnell,
# Nearest to issue: dismiss, hopeful, provisionally, eliminate, making, basis, investigation, ulema,
# Nearest to prince: crowned, lambeth, minos, umno, backer, ptolemaic, ell, sh,
# Nearest to dr: imaginings, handset, biographies, irritant, cohen, gilgal, phys, krueger,
# Nearest to test: gotten, insulators, telco, delay, affecting, fraggle, browsers, wario,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1793 0.1550 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1580 0.1651 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1946 0.1617 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2256 0.1515 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1241 0.1515 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1449 0.1527 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1600 0.1596 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1219 0.1498 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1867 0.1499 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2285 0.1500 sec/batch
# Nearest to however: linker, negatively, passageway, ruthenian, streptococcus, avoided, stylus, recession,
# Nearest to into: gie, reus, displaced, morrie, buckminster, sindhu, empty, asimo,
# Nearest to its: revoking, decarlo, vandalism, spo, warners, has, subordinate, ulterior,
# Nearest to have: many, unicef, seagal, censors, alphabetization, ltv, honolulu, allege,
# Nearest to an: minogue, tude, fly, xlv, piet, agains, eyeglasses, outranks,
# Nearest to many: organisations, have, transwomen, prospects, own, cults, some, nukem,
# Nearest to been: charted, redirected, forefront, accused, nothing, rejecting, evacuees, glider,
# Nearest to often: doctrines, printed, ultimate, sorceresses, qualifies, domineering, stoppages, cameroun,
# Nearest to institute: stanford, classicists, vocational, ld, institutions, phalange, faculty, constructor,
# Nearest to shown: aretha, coyote, clearances, keck, ferranti, bindings, approximated, musculus,
# Nearest to stage: morten, westernized, coffey, tie, portraying, htp, archie, piece,
# Nearest to defense: disregarded, combat, simulacrum, requires, lancer, cheeses, freedb, mcdonnell,
# Nearest to issue: dismiss, hopeful, making, eliminate, provisionally, basis, investigation, zhuyin,
# Nearest to prince: crowned, lambeth, umno, minos, monarch, episcopi, ptolemaic, castile,
# Nearest to dr: biographies, imaginings, cohen, irritant, phys, gilgal, krueger, chancellorsville,
# Nearest to test: insulators, telco, gotten, potos, wario, affecting, delay, mast,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2326 0.1560 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1357 0.1519 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1231 0.1545 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1366 0.1570 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0303 0.1496 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1593 0.1507 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1236 0.1513 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1308 0.1546 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1901 0.0198 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1363 0.1491 sec/batch
# Nearest to however: linker, negatively, passageway, ruthenian, avoided, streptococcus, visibly, should,
# Nearest to into: reus, retrieving, displaced, gie, asimo, empty, morrie, buckminster,
# Nearest to its: revoking, decarlo, warners, the, has, thwomps, ulterior, vandalism,
# Nearest to have: many, alphabetization, acceptable, ltv, unicef, censors, clos, seagal,
# Nearest to an: minogue, xlv, fly, outranks, tude, the, eyeglasses, piet,
# Nearest to many: organisations, have, transwomen, millimetres, some, nukem, diction, prospects,
# Nearest to been: charted, redirected, glider, forefront, evacuees, nothing, accused, taxonomy,
# Nearest to often: doctrines, printed, providing, taxes, confines, sorceresses, stoppages, companies,
# Nearest to institute: vocational, stanford, ld, classicists, mit, faculty, phalange, constructor,
# Nearest to shown: aretha, clearances, coyote, approximated, keck, ferranti, bindings, musculus,
# Nearest to stage: morten, westernized, portraying, htp, vitamin, coffey, tie, embryonic,
# Nearest to defense: disregarded, combat, simulacrum, lancer, freedb, mcdonnell, requires, llu,
# Nearest to issue: dismiss, hopeful, provisionally, eliminate, making, basis, anhui, investigation,
# Nearest to prince: lambeth, umno, crowned, minos, simitis, ell, episcopi, castile,
# Nearest to dr: imaginings, biographies, cohen, irritant, phys, gilgal, krueger, ramsay,
# Nearest to test: insulators, gotten, telco, potos, bloated, wario, mast, dumping,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0632 0.1498 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0389 0.1499 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1300 0.1500 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0498 0.1489 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0353 0.1489 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0270 0.1490 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0753 0.1495 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1043 0.1487 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1012 0.1511 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0522 0.1519 sec/batch
# Nearest to however: linker, passageway, negatively, visibly, null, streptococcus, share, ruthenian,
# Nearest to into: displaced, empty, gie, retrieving, asimo, reus, morrie, buckminster,
# Nearest to its: revoking, warners, has, the, decarlo, thwomps, applications, materialized,
# Nearest to have: many, alphabetization, unicef, acceptable, robes, ltv, iptv, allege,
# Nearest to an: minogue, fly, xlv, the, fabricating, eyeglasses, outranks, piet,
# Nearest to many: organisations, transwomen, have, some, prospects, diction, millimetres, cults,
# Nearest to been: charted, redirected, forefront, glider, accused, nothing, evacuees, hinterlands,
# Nearest to often: printed, doctrines, roll, sorceresses, ultimate, stoppages, providing, taxes,
# Nearest to institute: vocational, stanford, ld, classicists, faculty, polytechnic, mit, phalange,
# Nearest to shown: aretha, coyote, clearances, keck, ferranti, bindings, approximated, musculus,
# Nearest to stage: htp, morten, embryonic, vitamin, westernized, tie, various, fringes,
# Nearest to defense: combat, disregarded, lancer, simulacrum, demobilization, strategic, requires, weapons,
# Nearest to issue: dismiss, hopeful, making, eliminate, provisionally, basis, anhui, aliases,
# Nearest to prince: lambeth, umno, crowned, minos, ell, episcopi, monarch, prosper,
# Nearest to dr: imaginings, biographies, irritant, cohen, krueger, phys, ramsay, dirkjan,
# Nearest to test: telco, insulators, gotten, mast, potos, attracts, delay, wario,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0283 0.1501 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0041 0.1531 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0476 0.1491 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0540 0.1489 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0703 0.1527 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0460 0.1536 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0478 0.1528 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1331 0.1532 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0689 0.1659 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0206 0.1560 sec/batch
# Nearest to however: linker, negatively, passageway, null, commented, plays, share, ruthenian,
# Nearest to into: empty, displaced, retrieving, gie, reus, asimo, morrie, redaction,
# Nearest to its: revoking, warners, decarlo, the, has, spo, bbb, donald,
# Nearest to have: many, alphabetization, robes, acceptable, ltv, unicef, discernable, honolulu,
# Nearest to an: minogue, fly, xlv, the, dalet, fabricating, piet, outranks,
# Nearest to many: organisations, have, transwomen, some, gch, cults, millimetres, embracing,
# Nearest to been: charted, redirected, glider, forefront, nothing, accused, insights, survived,
# Nearest to often: doctrines, providing, qualifies, printed, roll, taxes, sorceresses, nicht,
# Nearest to institute: vocational, stanford, polytechnic, faculty, ld, classicists, mit, phalange,
# Nearest to shown: aretha, coyote, clearances, ferranti, approximated, bindings, ruining, keck,
# Nearest to stage: htp, fringes, westernized, various, vitamin, morten, neanderthalensis, embryonic,
# Nearest to defense: combat, simulacrum, lancer, disregarded, freedb, weapons, demobilization, mcdonnell,
# Nearest to issue: dismiss, hopeful, making, eliminate, provisionally, aliases, archiving, basis,
# Nearest to prince: lambeth, umno, minos, crowned, ell, monarch, episcopi, templi,
# Nearest to dr: imaginings, biographies, cohen, phys, krueger, dirkjan, chancellorsville, ramsay,
# Nearest to test: telco, insulators, wario, gotten, potos, affecting, dumping, delay,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0601 0.1590 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0600 0.1510 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0534 0.1527 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0623 0.1514 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0972 0.1524 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0110 0.1538 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0776 0.1499 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0798 0.1519 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0993 0.1583 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0549 0.1580 sec/batch
# Nearest to however: linker, ruthenian, negatively, null, passageway, share, enabled, commented,
# Nearest to into: displaced, gie, empty, retrieving, asimo, redaction, reus, sowed,
# Nearest to its: revoking, the, decarlo, has, warners, spo, as, bbb,
# Nearest to have: many, alphabetization, honolulu, ltv, acceptable, robes, discernable, tripitaka,
# Nearest to an: minogue, fly, xlv, tude, the, dalet, piet, demonstrates,
# Nearest to many: organisations, some, have, transwomen, cults, nukem, prospects, cuon,
# Nearest to been: redirected, charted, glider, survived, insights, forefront, nothing, accused,
# Nearest to often: doctrines, nicht, providing, sorceresses, roll, stoppages, taxes, predominate,
# Nearest to institute: vocational, polytechnic, stanford, ld, faculty, phalange, mit, classicists,
# Nearest to shown: aretha, coyote, clearances, bindings, keck, ruining, ferranti, approximated,
# Nearest to stage: htp, fringes, various, embryonic, westernized, vitamin, shiva, neanderthalensis,
# Nearest to defense: simulacrum, combat, lancer, disregarded, demobilization, freedb, weapons, llu,
# Nearest to issue: dismiss, hopeful, making, eliminate, provisionally, basis, ulema, aliases,
# Nearest to prince: monarch, crowned, lambeth, umno, minos, episcopi, castile, ell,
# Nearest to dr: imaginings, cohen, biographies, phys, krueger, dirkjan, irritant, allen,
# Nearest to test: telco, wario, potos, insulators, gotten, affecting, dumping, wont,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0524 0.1567 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0235 0.1539 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0353 0.1497 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0776 0.1495 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0509 0.1492 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1174 0.1504 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1100 0.1518 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0881 0.1505 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0239 0.1503 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0584 0.1495 sec/batch
# Nearest to however: linker, ruthenian, negatively, passageway, share, null, enabled, transmissive,
# Nearest to into: displaced, empty, gie, redaction, reus, asimo, retrieving, morrie,
# Nearest to its: revoking, the, decarlo, warners, has, spo, bbb, donald,
# Nearest to have: alphabetization, many, honolulu, acceptable, ltv, erstwhile, discernable, robes,
# Nearest to an: minogue, the, fly, tude, xlv, piet, demonstrates, dalet,
# Nearest to many: organisations, some, transwomen, have, cuon, cults, diction, gch,
# Nearest to been: redirected, charted, survived, forefront, glider, hinterlands, evacuees, accused,
# Nearest to often: doctrines, sorceresses, taxes, stoppages, predominate, qualifies, roll, confines,
# Nearest to institute: vocational, ld, polytechnic, stanford, faculty, phalange, classicists, mit,
# Nearest to shown: aretha, coyote, clearances, ruining, bindings, keck, ferranti, autobahn,
# Nearest to stage: htp, morten, vitamin, phobias, fringes, embryonic, various, westernized,
# Nearest to defense: simulacrum, disregarded, lancer, combat, weapons, freedb, demobilization, oncoming,
# Nearest to issue: dismiss, hopeful, making, basis, provisionally, eliminate, aliases, hafizullah,
# Nearest to prince: lambeth, monarch, umno, crowned, ell, minos, episcopi, godesberg,
# Nearest to dr: imaginings, biographies, phys, krueger, allen, harpers, dirkjan, ramsay,
# Nearest to test: telco, potos, wario, dumping, affecting, retort, insulators, wont,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0115 0.1510 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0159 0.1560 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0229 0.1617 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0432 0.1496 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0843 0.1494 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0575 0.1256 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0094 0.1491 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9996 0.1497 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0058 0.1496 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9567 0.1495 sec/batch
# Nearest to however: linker, share, passageway, negatively, null, enabled, ruthenian, and,
# Nearest to into: displaced, empty, gie, retrieving, ideograms, asimo, reus, sowed,
# Nearest to its: revoking, the, warners, decarlo, has, merthyr, donald, emulate,
# Nearest to have: alphabetization, many, robes, ltv, selves, erstwhile, honolulu, acceptable,
# Nearest to an: minogue, the, fly, piet, xlv, demonstrates, tude, preprint,
# Nearest to many: organisations, transwomen, some, cults, have, diction, gch, firmness,
# Nearest to been: redirected, charted, survived, accused, glider, hinterlands, forefront, insights,
# Nearest to often: doctrines, sorceresses, predominate, roll, taxes, nicht, stoppages, confines,
# Nearest to institute: vocational, polytechnic, ld, mit, stanford, phalange, faculty, classicists,
# Nearest to shown: aretha, coyote, clearances, ruining, bindings, treated, keck, ferranti,
# Nearest to stage: htp, various, embryonic, vitamin, fringes, phobias, neanderthalensis, shiva,
# Nearest to defense: simulacrum, combat, oncoming, disregarded, lancer, weapons, demobilization, freedb,
# Nearest to issue: dismiss, hopeful, making, eliminate, provisionally, basis, aliases, archiving,
# Nearest to prince: lambeth, monarch, umno, ell, crowned, hanazono, sh, isabella,
# Nearest to dr: imaginings, allen, biographies, phys, krueger, rashad, dirkjan, gilgal,
# Nearest to test: telco, potos, dumping, retort, wont, wario, attracts, visited,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0002 0.1513 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9615 0.1498 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0234 0.1496 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0129 0.1568 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0156 0.1559 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0092 0.1572 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9027 0.1548 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9577 0.1602 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9483 0.1542 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9629 0.1516 sec/batch
# Nearest to however: linker, negatively, share, ruthenian, passageway, waist, avoided, only,
# Nearest to into: empty, displaced, ideograms, retrieving, gie, sowed, redaction, modifies,
# Nearest to its: revoking, the, warners, has, decarlo, spo, as, carotenoid,
# Nearest to have: many, ltv, and, honolulu, alphabetization, lepidus, allege, robes,
# Nearest to an: the, minogue, fly, piet, eolian, demonstrates, pennant, zseries,
# Nearest to many: organisations, some, transwomen, have, firmness, millimetres, advertisers, nukem,
# Nearest to been: redirected, charted, survived, glider, bisexuals, marksmen, warmest, hinterlands,
# Nearest to often: doctrines, sorceresses, nicht, cameroun, predominate, also, roll, stoppages,
# Nearest to institute: polytechnic, vocational, ld, phalange, mit, stanford, faculty, classicists,
# Nearest to shown: aretha, coyote, clearances, ruining, bindings, treated, plano, ferranti,
# Nearest to stage: htp, fringes, various, neanderthalensis, embryonic, shiva, vitamin, westernized,
# Nearest to defense: simulacrum, combat, lancer, oncoming, disregarded, strategic, demobilization, weapons,
# Nearest to issue: dismiss, making, hopeful, eliminate, archiving, provisionally, basis, aliases,
# Nearest to prince: lambeth, umno, monarch, ell, godesberg, crowned, hanazono, episcopi,
# Nearest to dr: imaginings, phys, biographies, allen, harpers, poz, vascular, dirkjan,
# Nearest to test: telco, dumping, potos, bowled, wont, visited, retort, tests,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9817 0.1603 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0208 0.1619 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9926 0.1579 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0420 0.1596 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0353 0.1602 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9674 0.1558 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9729 0.1602 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0030 0.1586 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0138 0.1604 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9797 0.1608 sec/batch
# Nearest to however: linker, share, negatively, robson, enabled, and, commented, selling,
# Nearest to into: empty, displaced, retrieving, ideograms, asimo, gie, goddard, mszp,
# Nearest to its: revoking, the, warners, as, decarlo, has, this, donald,
# Nearest to have: many, ltv, robes, alphabetization, and, lepidus, tripitaka, unicef,
# Nearest to an: minogue, the, piet, outranks, demonstrates, preprint, dalet, weschler,
# Nearest to many: organisations, some, have, transwomen, firmness, nukem, cults, advertisers,
# Nearest to been: charted, redirected, survived, shivers, glider, harum, warmest, sweeping,
# Nearest to often: also, cameroun, nicht, predominate, roll, sorceresses, doctrines, stoppages,
# Nearest to institute: polytechnic, vocational, ld, stanford, phalange, mit, moorehead, classicists,
# Nearest to shown: aretha, coyote, ruining, clearances, ferranti, bindings, educating, keck,
# Nearest to stage: htp, fringes, various, embryonic, shiva, neanderthalensis, westernized, vitamin,
# Nearest to defense: combat, simulacrum, disregarded, lancer, oncoming, strategic, demobilization, taft,
# Nearest to issue: dismiss, making, hopeful, eliminate, archiving, aliases, basis, provisionally,
# Nearest to prince: monarch, lambeth, hanazono, umno, sh, crowned, ell, throne,
# Nearest to dr: phys, imaginings, allen, dirkjan, biographies, krueger, harpers, vascular,
# Nearest to test: telco, potos, dumping, bowled, wont, wario, retort, tests,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0077 0.1639 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9899 0.1580 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9746 0.1534 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0310 0.1554 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9850 0.1604 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0037 0.1594 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9738 0.1598 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9226 0.1646 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9744 0.1640 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0167 0.1605 sec/batch
# Nearest to however: and, share, linker, only, bahasa, ruthenian, warlordism, negatively,
# Nearest to into: displaced, empty, gie, mszp, ideograms, nathan, reestablishing, goddard,
# Nearest to its: the, revoking, as, has, from, but, this, in,
# Nearest to have: many, alphabetization, ltv, and, some, acceptable, allege, standard,
# Nearest to an: the, minogue, piet, preprint, tude, has, that, is,
# Nearest to many: organisations, some, have, firmness, transwomen, cults, advertisers, nukem,
# Nearest to been: charted, redirected, survived, since, bisexuals, accused, sweeping, forefront,
# Nearest to often: also, cameroun, predominate, sorceresses, both, nicht, harnesses, licensee,
# Nearest to institute: polytechnic, vocational, ld, stanford, phalange, mit, moorehead, classicists,
# Nearest to shown: coyote, aretha, ruining, treated, educating, clearances, denumerable, bindings,
# Nearest to stage: htp, embryonic, various, fringes, shiva, westernized, neanderthalensis, vitamin,
# Nearest to defense: combat, simulacrum, disregarded, oncoming, lancer, weapons, demobilization, strategic,
# Nearest to issue: dismiss, making, hopeful, eliminate, basis, archiving, aliases, provisionally,
# Nearest to prince: monarch, hanazono, lambeth, umno, ell, throne, sh, managed,
# Nearest to dr: biographies, phys, allen, imaginings, dirkjan, rashad, cohen, gilgal,
# Nearest to test: dumping, potos, telco, tests, bowled, desertification, retort, basenji,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9707 0.1627 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0704 0.1672 sec/batch
# ...
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7465 0.1510 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8312 0.1516 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7903 0.1518 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7851 0.1514 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8261 0.1516 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8890 0.1514 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8250 0.1514 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8723 0.1517 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9337 0.1562 sec/batch
# Nearest to however: and, not, have, only, many, had, that, though,
# Nearest to into: the, and, nathan, goddard, displaced, from, descending, receded,
# Nearest to its: the, as, in, of, with, is, has, from,
# Nearest to have: and, many, are, however, some, though, from, in,
# Nearest to an: the, and, a, for, is, in, of, to,
# Nearest to many: have, some, including, however, as, also, and, other,
# Nearest to been: since, survived, honoria, were, also, marksmen, was, have,
# Nearest to often: also, both, predominate, examples, borderline, slither, reunions, comedies,
# Nearest to institute: polytechnic, phalange, mit, birla, sherwin, kristianstad, moorehead, vocational,
# Nearest to shown: shows, aretha, gag, unsaturated, contemporaneous, beag, ehret, ruining,
# Nearest to stage: htp, embryonic, shiva, restraint, overshadowed, giacomo, morten, phobias,
# Nearest to defense: lancer, linebackers, simulacrum, offense, llu, brady, grumman, freedb,
# Nearest to issue: hopeful, rebelled, eliminate, aliases, dismiss, archiving, cholerae, making,
# Nearest to prince: monarch, hanazono, probate, clan, rhodium, tei, walden, licence,
# Nearest to dr: poz, phys, allen, hint, krueger, rashad, academy, inland,
# Nearest to test: tests, bowled, batsman, dumping, marpol, telco, ifr, navarrese,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8555 0.1494 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8342 0.1466 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8456 0.1465 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8826 0.1469 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8700 0.1466 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.9006 0.1471 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8599 0.1469 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8427 0.1467 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8922 0.1469 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8682 0.1467 sec/batch
# Nearest to however: not, have, many, and, only, had, that, as,
# Nearest to into: the, and, goddard, descending, nathan, from, displaced, receded,
# Nearest to its: the, as, in, of, has, is, with, revoking,
# Nearest to have: are, many, and, however, some, in, though, not,
# Nearest to an: the, and, a, of, for, is, part, in,
# Nearest to many: some, have, however, including, organisations, other, also, underpinnings,
# Nearest to been: also, honoria, were, survived, was, since, have, marksmen,
# Nearest to often: also, both, predominate, examples, slither, reunions, most, borderline,
# Nearest to institute: polytechnic, phalange, birla, sherwin, mit, kristianstad, moorehead, ld,
# Nearest to shown: aretha, shows, contemporaneous, ehret, beag, educating, ruining, coyote,
# Nearest to stage: htp, embryonic, shiva, restraint, overshadowed, vaudeville, discriminated, morten,
# Nearest to defense: lancer, linebackers, simulacrum, llu, freedb, grumman, unfccc, combat,
# Nearest to issue: hopeful, rebelled, aliases, eliminate, dismiss, archiving, resold, heroines,
# Nearest to prince: monarch, clan, hanazono, probate, princess, sh, licence, apparent,
# Nearest to dr: poz, phys, hint, krueger, rashad, allen, single, vascular,
# Nearest to test: tests, bowled, dumping, batsman, marpol, navarrese, macrae, basenji,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8510 0.1481 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8461 0.1470 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8267 0.1465 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8377 0.1464 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8869 0.1465 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8369 0.1473 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9785 0.1469 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8785 0.1470 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9110 0.1469 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8037 0.1470 sec/batch
# Nearest to however: not, have, many, had, though, that, only, and,
# Nearest to into: the, nathan, descending, goddard, and, receded, displaced, was,
# Nearest to its: the, as, with, of, in, has, is, revoking,
# Nearest to have: are, however, many, some, and, though, from, not,
# Nearest to an: the, and, of, in, for, is, a, part,
# Nearest to many: some, including, however, have, other, organisations, most, also,
# Nearest to been: honoria, since, also, survived, were, was, marksmen, woese,
# Nearest to often: also, predominate, slither, examples, borderline, both, reunions, most,
# Nearest to institute: phalange, polytechnic, sherwin, birla, mit, moorehead, ld, kristianstad,
# Nearest to shown: aretha, shows, beag, gag, pasiphae, contemporaneous, ruining, ehret,
# Nearest to stage: embryonic, restraint, vaudeville, htp, overshadowed, morten, shiva, giacomo,
# Nearest to defense: lancer, linebackers, simulacrum, freedb, unfccc, llu, offense, brady,
# Nearest to issue: hopeful, rebelled, aliases, ia, eliminate, dismiss, hampden, archiving,
# Nearest to prince: monarch, hanazono, probate, clan, licence, princess, throne, walden,
# Nearest to dr: poz, phys, krueger, hint, rashad, allen, garz, psychiatrist,
# Nearest to test: tests, bowled, marpol, dumping, batsman, navarrese, basenji, ifr,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8117 0.1479 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8348 0.1461 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7526 0.1465 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8841 0.1466 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8587 0.1474 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8336 0.1470 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9189 0.0575 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8151 0.1472 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8092 0.1471 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8451 0.1468 sec/batch
# Nearest to however: have, not, though, that, many, only, had, the,
# Nearest to into: the, and, descending, goddard, receded, nathan, from, was,
# Nearest to its: the, as, of, with, is, in, from, a,
# Nearest to have: however, are, many, and, some, though, to, from,
# Nearest to an: the, is, and, a, of, for, part, in,
# Nearest to many: some, have, including, however, among, other, most, also,
# Nearest to been: were, was, since, survived, honoria, have, also, marksmen,
# Nearest to often: predominate, also, both, slither, borderline, examples, reunions, most,
# Nearest to institute: phalange, polytechnic, birla, sherwin, mit, moorehead, ld, nist,
# Nearest to shown: aretha, shows, unknown, contemporaneous, beag, pasiphae, gag, ehret,
# Nearest to stage: embryonic, htp, restraint, overshadowed, vaudeville, shiva, lbf, jaxa,
# Nearest to defense: linebackers, lancer, offense, simulacrum, llu, combat, freedb, weapons,
# Nearest to issue: rebelled, hopeful, aliases, eliminate, ia, hampden, resold, dismiss,
# Nearest to prince: monarch, hanazono, probate, walden, princess, licence, clan, rhodium,
# Nearest to dr: poz, hint, krueger, rashad, garz, phys, academy, psychiatrist,
# Nearest to test: tests, bowled, marpol, batsman, dumping, testing, navarrese, cricket,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8526 0.1479 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8191 0.1469 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8206 0.1467 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7746 0.1466 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8531 0.1468 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8430 0.1465 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.9020 0.1466 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7674 0.1461 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7953 0.1460 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8531 0.1459 sec/batch
# Nearest to however: not, have, and, though, many, only, that, the,
# Nearest to into: the, and, from, of, chloroplast, by, descending, nathan,
# Nearest to its: the, as, of, is, in, with, a, from,
# Nearest to have: and, are, many, however, to, some, from, in,
# Nearest to an: the, a, and, is, for, in, to, of,
# Nearest to many: have, some, including, however, also, and, among, other,
# Nearest to been: was, have, were, survived, since, honoria, also, still,
# Nearest to often: also, both, most, examples, predominate, other, usually, sometimes,
# Nearest to institute: polytechnic, sherwin, phalange, birla, mit, moorehead, kristianstad, ld,
# Nearest to shown: shows, aretha, beag, denumerable, gag, arrive, an, case,
# Nearest to stage: htp, restraint, embryonic, shiva, lbf, giacomo, vaudeville, overshadowed,
# Nearest to defense: lancer, linebackers, offense, combat, simulacrum, llu, grumman, brady,
# Nearest to issue: hopeful, rebelled, eliminate, archiving, aliases, cholerae, dismiss, hampden,
# Nearest to prince: hanazono, monarch, probate, licence, walden, tei, princess, apparent,
# Nearest to dr: poz, krueger, hint, rashad, phys, garz, vascular, single,
# Nearest to test: tests, bowled, marpol, dumping, batsman, testing, navarrese, cricket,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7347 0.1475 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8174 0.1465 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8784 0.1466 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8285 0.1465 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8259 0.1467 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9124 0.1465 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8341 0.1467 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8098 0.1478 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8434 0.1469 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8564 0.1471 sec/batch
# Nearest to however: not, have, and, many, though, only, as, the,
# Nearest to into: the, and, of, nathan, chloroplast, goddard, stumble, from,
# Nearest to its: the, as, of, in, is, with, has, a,
# Nearest to have: are, and, many, however, some, to, not, though,
# Nearest to an: the, is, a, and, of, for, to, in,
# Nearest to many: have, some, however, including, among, as, also, other,
# Nearest to been: was, survived, have, since, honoria, were, likely, also,
# Nearest to often: also, both, reunions, predominate, borderline, most, slither, comedies,
# Nearest to institute: polytechnic, birla, phalange, sherwin, mit, kristianstad, moorehead, nist,
# Nearest to shown: shows, aretha, gag, beag, denumerable, arrive, unknown, contemporaneous,
# Nearest to stage: embryonic, shiva, htp, restraint, vaudeville, overshadowed, giacomo, lbf,
# Nearest to defense: linebackers, lancer, offense, simulacrum, llu, combat, unfccc, grumman,
# Nearest to issue: rebelled, hopeful, aliases, cholerae, eliminate, dismiss, archiving, heroines,
# Nearest to prince: monarch, clan, hanazono, probate, throne, princess, tei, walden,
# Nearest to dr: poz, rap, hint, krueger, single, garz, phys, rashad,
# Nearest to test: tests, bowled, marpol, testing, navarrese, dumping, batsman, basenji,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8519 0.1479 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8476 0.1463 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8224 0.1469 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8628 0.1467 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8481 0.1469 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8423 0.1470 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8506 0.1466 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8291 0.1459 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8225 0.1463 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8286 0.1466 sec/batch
# Nearest to however: not, and, have, many, the, only, that, as,
# Nearest to into: the, and, of, from, displaced, chloroplast, goddard, nathan,
# Nearest to its: the, as, of, in, is, with, that, itself,
# Nearest to have: are, however, some, and, many, in, to, not,
# Nearest to an: the, and, is, a, of, in, to, for,
# Nearest to many: some, however, have, other, as, also, most, including,
# Nearest to been: was, survived, have, were, honoria, since, likely, blackfeet,
# Nearest to often: also, most, both, usually, predominate, reunions, sometimes, as,
# Nearest to institute: polytechnic, birla, phalange, sherwin, mit, moorehead, nist, kristianstad,
# Nearest to shown: shows, aretha, denumerable, beag, an, contemporaneous, case, following,
# Nearest to stage: embryonic, restraint, shiva, htp, giacomo, discriminated, westernized, overshadowed,
# Nearest to defense: lancer, linebackers, llu, offense, unfccc, simulacrum, weapons, brady,
# Nearest to issue: rebelled, hopeful, aliases, eliminate, cholerae, ulema, archiving, ia,
# Nearest to prince: monarch, hanazono, probate, clan, licence, princess, throne, walden,
# Nearest to dr: poz, hint, rap, krueger, phys, garz, rashad, radial,
# Nearest to test: tests, bowled, testing, navarrese, dumping, marpol, batsman, ifr,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8587 0.1483 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8203 0.1467 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8658 0.1470 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8765 0.1467 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9116 0.1466 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8427 0.1467 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7691 0.1463 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8273 0.1464 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7201 0.1471 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8552 0.1464 sec/batch
# Nearest to however: many, not, have, though, the, that, and, only,
# Nearest to into: the, and, chloroplast, goddard, from, of, nathan, displaced,
# Nearest to its: the, as, of, in, with, is, itself, has,
# Nearest to have: are, however, some, many, and, though, from, not,
# Nearest to an: the, and, a, is, of, in, for, part,
# Nearest to many: however, some, including, have, also, other, as, most,
# Nearest to been: was, since, survived, have, honoria, were, marksmen, likely,
# Nearest to often: also, both, most, predominate, reunions, as, usually, sometimes,
# Nearest to institute: polytechnic, birla, phalange, sherwin, mit, moorehead, nist, ld,
# Nearest to shown: aretha, shows, an, contemporaneous, beag, denumerable, case, unknown,
# Nearest to stage: embryonic, giacomo, overshadowed, vaudeville, morten, restraint, lbf, htp,
# Nearest to defense: lancer, llu, linebackers, offense, combat, simulacrum, unfccc, grumman,
# Nearest to issue: rebelled, hopeful, eliminate, aliases, cholerae, hampden, ia, heroines,
# Nearest to prince: hanazono, monarch, probate, clan, licence, walden, tei, princess,
# Nearest to dr: poz, rap, phys, garz, krueger, hint, rashad, academy,
# Nearest to test: tests, bowled, testing, batsman, navarrese, dumping, basenji, marpol,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8404 0.1479 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8577 0.1468 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('../../../Data/For_emmbedding/checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
