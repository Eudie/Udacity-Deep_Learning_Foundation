# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [08:05, 351KB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 9
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 9:
# Image - Min Value: 11 Max Value: 218
# Image - Shape: (32, 32, 3)
# Label - Label Id: 3 Name: cat

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
import numpy as np
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    x = np.array(x)
    x_max = np.max(x)
    x_min = np.min(x)
    output = (x - x_min)/(x_max - x_min)
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
lb.fit(range(10))
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    
    return lb.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper
# import matplotlib.pyplot as plt
# from sklearn.preprocessing import LabelBinarizer

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# If you're finding it hard to dedicate enough time for this course a week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) to build each layer, except "Convolutional & Max Pooling" layer.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# If you would like to get the most of this course, try to solve all the problems without TF Layers.  Let's begin!
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape = (None, image_shape[0], image_shape[1], image_shape[2]), name = 'x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape = (None, n_classes), name = 'y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape = (None), name = 'keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# Note: You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.  You're free to use any TensorFlow package for all the other layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    shape_of_x_tensor = x_tensor.get_shape().as_list()
    F_W = tf.Variable(tf.truncated_normal([conv_ksize[0] ,conv_ksize[1] ,shape_of_x_tensor[-1] ,conv_num_outputs] 
                                          ,dtype=tf.float32, stddev=0.2))
    F_b = tf.Variable(tf.zeros([conv_num_outputs]  ,dtype=tf.float32))
    strides_conv = [1, conv_strides[0], conv_strides[1], 1]
    padding = 'SAME'
    output = tf.nn.conv2d(x_tensor, F_W, strides_conv, padding)
    output = tf.nn.bias_add(output, F_b)
    output = tf.nn.relu(output)
    ksize_maxpool = [1, pool_ksize[0], pool_ksize[1], 1]
    strides_maxpool = [1, pool_strides[0], pool_strides[1], 1]
    output = tf.nn.max_pool(output, ksize_maxpool, strides_maxpool, padding)
    
    return output 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    flat_dim = shape[1]*shape[2]*shape[3]
    output = tf.reshape(x_tensor, [-1, flat_dim])
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    weights= tf.Variable(tf.truncated_normal([shape[1], num_outputs] ,dtype=tf.float32, stddev=0.2))
    biases = tf.Variable(tf.zeros([num_outputs]  ,dtype=tf.float32))
    out = tf.add(tf.matmul(x_tensor, weights), biases)
    out = tf.nn.relu(out)
    return out

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.
#
# Note: Activation, softmax, or cross entropy shouldn't be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    shape = x_tensor.get_shape().as_list()
    weights= tf.Variable(tf.truncated_normal([shape[1], num_outputs] ,dtype=tf.float32, stddev=0.2))
    biases = tf.Variable(tf.zeros([num_outputs]  ,dtype=tf.float32))
    out = tf.add(tf.matmul(x_tensor, weights), biases)
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    out = conv2d_maxpool(x, conv_num_outputs = 16, conv_ksize = (3,3), conv_strides = (1,1), pool_ksize=(2,2), pool_strides=(2,2))
    out = conv2d_maxpool(out, conv_num_outputs = 32, conv_ksize = (3,3), conv_strides = (1,1), pool_ksize=(2,2), pool_strides=(2,2))
    out = conv2d_maxpool(out, conv_num_outputs = 64, conv_ksize = (3,3), conv_strides = (1,1), pool_ksize=(2,2), pool_strides=(2,2))

    # Function Definition from Above:
    out = flatten(out)
    
    
    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    out = fully_conn(out, num_outputs = 64)
    out = tf.nn.dropout(out, keep_prob)
    out = fully_conn(out, num_outputs = 32)
    out = tf.nn.dropout(out, keep_prob)
    out = fully_conn(out, num_outputs = 16)
    #    Set this to the number of classes
    # Function Definition from Above:
    out = output(out, num_outputs = 10)

    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch,keep_prob:keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    valid_acc = sess.run(accuracy, feed_dict={
                x: valid_features,
                y: valid_labels,
                keep_prob: 1.})
    train_acc = sess.run(accuracy, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: 1.})
    train_cost = sess.run(cost, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: 1.})
    print('Cost {::>8.5f}, Accuracy on Training {:.4f} -'
                  'Validation Accuracy: {:.4f}'.format(
                train_cost,
                train_acc,
                valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 256
keep_probability = 0.6

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Cost :2.30015, Accuracy on Training 0.1250 -Validation Accuracy: 0.1010
# Epoch  2, CIFAR-10 Batch 1:  Cost :2.29247, Accuracy on Training 0.1250 -Validation Accuracy: 0.1398
# Epoch  3, CIFAR-10 Batch 1:  Cost :2.26395, Accuracy on Training 0.2000 -Validation Accuracy: 0.1956
# Epoch  4, CIFAR-10 Batch 1:  Cost :2.24066, Accuracy on Training 0.1500 -Validation Accuracy: 0.2184
# Epoch  5, CIFAR-10 Batch 1:  Cost :2.16076, Accuracy on Training 0.1750 -Validation Accuracy: 0.2352
# Epoch  6, CIFAR-10 Batch 1:  Cost :2.08136, Accuracy on Training 0.2500 -Validation Accuracy: 0.2682
# Epoch  7, CIFAR-10 Batch 1:  Cost :2.02686, Accuracy on Training 0.3250 -Validation Accuracy: 0.2888
# Epoch  8, CIFAR-10 Batch 1:  Cost :1.94888, Accuracy on Training 0.3500 -Validation Accuracy: 0.2980
# Epoch  9, CIFAR-10 Batch 1:  Cost :1.92903, Accuracy on Training 0.3000 -Validation Accuracy: 0.2704
# Epoch 10, CIFAR-10 Batch 1:  Cost :1.86200, Accuracy on Training 0.4250 -Validation Accuracy: 0.3052
# Epoch 11, CIFAR-10 Batch 1:  Cost :1.83597, Accuracy on Training 0.4250 -Validation Accuracy: 0.3366
# Epoch 12, CIFAR-10 Batch 1:  Cost :1.75672, Accuracy on Training 0.4000 -Validation Accuracy: 0.3458
# Epoch 13, CIFAR-10 Batch 1:  Cost :1.71183, Accuracy on Training 0.4500 -Validation Accuracy: 0.3560
# Epoch 14, CIFAR-10 Batch 1:  Cost :1.68124, Accuracy on Training 0.4000 -Validation Accuracy: 0.3644
# Epoch 15, CIFAR-10 Batch 1:  Cost :1.65365, Accuracy on Training 0.4500 -Validation Accuracy: 0.3750
# Epoch 16, CIFAR-10 Batch 1:  Cost :1.56855, Accuracy on Training 0.5250 -Validation Accuracy: 0.3826
# Epoch 17, CIFAR-10 Batch 1:  Cost :1.52898, Accuracy on Training 0.4750 -Validation Accuracy: 0.3780
# Epoch 18, CIFAR-10 Batch 1:  Cost :1.49839, Accuracy on Training 0.5500 -Validation Accuracy: 0.4000
# Epoch 19, CIFAR-10 Batch 1:  Cost :1.43964, Accuracy on Training 0.5250 -Validation Accuracy: 0.4006
# Epoch 20, CIFAR-10 Batch 1:  Cost :1.43973, Accuracy on Training 0.5250 -Validation Accuracy: 0.3964
# Epoch 21, CIFAR-10 Batch 1:  Cost :1.42265, Accuracy on Training 0.5500 -Validation Accuracy: 0.3968
# Epoch 22, CIFAR-10 Batch 1:  Cost :1.35307, Accuracy on Training 0.6750 -Validation Accuracy: 0.4212
# Epoch 23, CIFAR-10 Batch 1:  Cost :1.35192, Accuracy on Training 0.5750 -Validation Accuracy: 0.4026
# Epoch 24, CIFAR-10 Batch 1:  Cost :1.32342, Accuracy on Training 0.5750 -Validation Accuracy: 0.4060
# Epoch 25, CIFAR-10 Batch 1:  Cost :1.25481, Accuracy on Training 0.5500 -Validation Accuracy: 0.4136
# Epoch 26, CIFAR-10 Batch 1:  Cost :1.21251, Accuracy on Training 0.6250 -Validation Accuracy: 0.4292
# Epoch 27, CIFAR-10 Batch 1:  Cost :1.15324, Accuracy on Training 0.6000 -Validation Accuracy: 0.4416
# Epoch 28, CIFAR-10 Batch 1:  Cost :1.11081, Accuracy on Training 0.5500 -Validation Accuracy: 0.4456
# Epoch 29, CIFAR-10 Batch 1:  Cost :1.11301, Accuracy on Training 0.6250 -Validation Accuracy: 0.4464
# Epoch 30, CIFAR-10 Batch 1:  Cost :1.09391, Accuracy on Training 0.6750 -Validation Accuracy: 0.4500
# Epoch 31, CIFAR-10 Batch 1:  Cost :1.01688, Accuracy on Training 0.6750 -Validation Accuracy: 0.4606
# Epoch 32, CIFAR-10 Batch 1:  Cost :1.00100, Accuracy on Training 0.6250 -Validation Accuracy: 0.4672
# Epoch 33, CIFAR-10 Batch 1:  Cost :0.99244, Accuracy on Training 0.6500 -Validation Accuracy: 0.4620
# Epoch 34, CIFAR-10 Batch 1:  Cost :0.95655, Accuracy on Training 0.6750 -Validation Accuracy: 0.4768
# Epoch 35, CIFAR-10 Batch 1:  Cost :0.93929, Accuracy on Training 0.6750 -Validation Accuracy: 0.4516
# Epoch 36, CIFAR-10 Batch 1:  Cost :0.93307, Accuracy on Training 0.6750 -Validation Accuracy: 0.4652
# Epoch 37, CIFAR-10 Batch 1:  Cost :0.87758, Accuracy on Training 0.7000 -Validation Accuracy: 0.4866
# Epoch 38, CIFAR-10 Batch 1:  Cost :0.86057, Accuracy on Training 0.6750 -Validation Accuracy: 0.4878
# Epoch 39, CIFAR-10 Batch 1:  Cost :0.88423, Accuracy on Training 0.6250 -Validation Accuracy: 0.4844
# Epoch 40, CIFAR-10 Batch 1:  Cost :0.84745, Accuracy on Training 0.7000 -Validation Accuracy: 0.4856
# Epoch 41, CIFAR-10 Batch 1:  Cost :0.82041, Accuracy on Training 0.7000 -Validation Accuracy: 0.4862
# Epoch 42, CIFAR-10 Batch 1:  Cost :0.76914, Accuracy on Training 0.7250 -Validation Accuracy: 0.4990
# Epoch 43, CIFAR-10 Batch 1:  Cost :0.74983, Accuracy on Training 0.7750 -Validation Accuracy: 0.5010
# Epoch 44, CIFAR-10 Batch 1:  Cost :0.77123, Accuracy on Training 0.7750 -Validation Accuracy: 0.5082
# Epoch 45, CIFAR-10 Batch 1:  Cost :0.73025, Accuracy on Training 0.7500 -Validation Accuracy: 0.5210
# Epoch 46, CIFAR-10 Batch 1:  Cost :0.71556, Accuracy on Training 0.7000 -Validation Accuracy: 0.5066
# Epoch 47, CIFAR-10 Batch 1:  Cost :0.71996, Accuracy on Training 0.7500 -Validation Accuracy: 0.5016
# Epoch 48, CIFAR-10 Batch 1:  Cost :0.71176, Accuracy on Training 0.7750 -Validation Accuracy: 0.5190
# Epoch 49, CIFAR-10 Batch 1:  Cost :0.69417, Accuracy on Training 0.7500 -Validation Accuracy: 0.5184
# Epoch 50, CIFAR-10 Batch 1:  Cost :0.69365, Accuracy on Training 0.8250 -Validation Accuracy: 0.5170
# Epoch 51, CIFAR-10 Batch 1:  Cost :0.65218, Accuracy on Training 0.7750 -Validation Accuracy: 0.5200
# Epoch 52, CIFAR-10 Batch 1:  Cost :0.65974, Accuracy on Training 0.7750 -Validation Accuracy: 0.5124
# Epoch 53, CIFAR-10 Batch 1:  Cost :0.64691, Accuracy on Training 0.8000 -Validation Accuracy: 0.5150
# Epoch 54, CIFAR-10 Batch 1:  Cost :0.62680, Accuracy on Training 0.8250 -Validation Accuracy: 0.5286
# Epoch 55, CIFAR-10 Batch 1:  Cost :0.62263, Accuracy on Training 0.8500 -Validation Accuracy: 0.5298
# Epoch 56, CIFAR-10 Batch 1:  Cost :0.58616, Accuracy on Training 0.8250 -Validation Accuracy: 0.5294
# Epoch 57, CIFAR-10 Batch 1:  Cost :0.59660, Accuracy on Training 0.8000 -Validation Accuracy: 0.5264
# Epoch 58, CIFAR-10 Batch 1:  Cost :0.59266, Accuracy on Training 0.8250 -Validation Accuracy: 0.5106
# Epoch 59, CIFAR-10 Batch 1:  Cost :0.59468, Accuracy on Training 0.8000 -Validation Accuracy: 0.5342
# Epoch 60, CIFAR-10 Batch 1:  Cost :0.58485, Accuracy on Training 0.8000 -Validation Accuracy: 0.5186
# Epoch 61, CIFAR-10 Batch 1:  Cost :0.59613, Accuracy on Training 0.8000 -Validation Accuracy: 0.5274
# Epoch 62, CIFAR-10 Batch 1:  Cost :0.56117, Accuracy on Training 0.8250 -Validation Accuracy: 0.5182
# Epoch 63, CIFAR-10 Batch 1:  Cost :0.51994, Accuracy on Training 0.8250 -Validation Accuracy: 0.5318
# Epoch 64, CIFAR-10 Batch 1:  Cost :0.55018, Accuracy on Training 0.7750 -Validation Accuracy: 0.5140
# Epoch 65, CIFAR-10 Batch 1:  Cost :0.51854, Accuracy on Training 0.7750 -Validation Accuracy: 0.5274
# Epoch 66, CIFAR-10 Batch 1:  Cost :0.50393, Accuracy on Training 0.8750 -Validation Accuracy: 0.5294
# Epoch 67, CIFAR-10 Batch 1:  Cost :0.52491, Accuracy on Training 0.8250 -Validation Accuracy: 0.5136
# Epoch 68, CIFAR-10 Batch 1:  Cost :0.53393, Accuracy on Training 0.8000 -Validation Accuracy: 0.5102
# Epoch 69, CIFAR-10 Batch 1:  Cost :0.48272, Accuracy on Training 0.8750 -Validation Accuracy: 0.5344
# Epoch 70, CIFAR-10 Batch 1:  Cost :0.47551, Accuracy on Training 0.8750 -Validation Accuracy: 0.5274
# Epoch 71, CIFAR-10 Batch 1:  Cost :0.49900, Accuracy on Training 0.8500 -Validation Accuracy: 0.5230
# Epoch 72, CIFAR-10 Batch 1:  Cost :0.46247, Accuracy on Training 0.8750 -Validation Accuracy: 0.5404
# Epoch 73, CIFAR-10 Batch 1:  Cost :0.44829, Accuracy on Training 0.8750 -Validation Accuracy: 0.5304
# Epoch 74, CIFAR-10 Batch 1:  Cost :0.43894, Accuracy on Training 0.8750 -Validation Accuracy: 0.5438
# Epoch 75, CIFAR-10 Batch 1:  Cost :0.48285, Accuracy on Training 0.8500 -Validation Accuracy: 0.5332
# Epoch 76, CIFAR-10 Batch 1:  Cost :0.44379, Accuracy on Training 0.8500 -Validation Accuracy: 0.5372
# Epoch 77, CIFAR-10 Batch 1:  Cost :0.42364, Accuracy on Training 0.9000 -Validation Accuracy: 0.5462
# Epoch 78, CIFAR-10 Batch 1:  Cost :0.42110, Accuracy on Training 0.9000 -Validation Accuracy: 0.5324
# Epoch 79, CIFAR-10 Batch 1:  Cost :0.44291, Accuracy on Training 0.9000 -Validation Accuracy: 0.5290
# Epoch 80, CIFAR-10 Batch 1:  Cost :0.47608, Accuracy on Training 0.8750 -Validation Accuracy: 0.5294
# Epoch 81, CIFAR-10 Batch 1:  Cost :0.41898, Accuracy on Training 0.9000 -Validation Accuracy: 0.5434
# Epoch 82, CIFAR-10 Batch 1:  Cost :0.42199, Accuracy on Training 0.8750 -Validation Accuracy: 0.5442
# Epoch 83, CIFAR-10 Batch 1:  Cost :0.41643, Accuracy on Training 0.8250 -Validation Accuracy: 0.5456
# Epoch 84, CIFAR-10 Batch 1:  Cost :0.41321, Accuracy on Training 0.8750 -Validation Accuracy: 0.5344
# Epoch 85, CIFAR-10 Batch 1:  Cost :0.39241, Accuracy on Training 0.8500 -Validation Accuracy: 0.5394
# Epoch 86, CIFAR-10 Batch 1:  Cost :0.39965, Accuracy on Training 0.8750 -Validation Accuracy: 0.5426
# Epoch 87, CIFAR-10 Batch 1:  Cost :0.39634, Accuracy on Training 0.8750 -Validation Accuracy: 0.5376
# Epoch 88, CIFAR-10 Batch 1:  Cost :0.41447, Accuracy on Training 0.9000 -Validation Accuracy: 0.5326
# Epoch 89, CIFAR-10 Batch 1:  Cost :0.39416, Accuracy on Training 0.9000 -Validation Accuracy: 0.5358
# Epoch 90, CIFAR-10 Batch 1:  Cost :0.38798, Accuracy on Training 0.8500 -Validation Accuracy: 0.5446
# Epoch 91, CIFAR-10 Batch 1:  Cost :0.36552, Accuracy on Training 0.8750 -Validation Accuracy: 0.5422
# Epoch 92, CIFAR-10 Batch 1:  Cost :0.37200, Accuracy on Training 0.8750 -Validation Accuracy: 0.5372
# Epoch 93, CIFAR-10 Batch 1:  Cost :0.36663, Accuracy on Training 0.8750 -Validation Accuracy: 0.5304
# Epoch 94, CIFAR-10 Batch 1:  Cost :0.34528, Accuracy on Training 0.9000 -Validation Accuracy: 0.5550
# Epoch 95, CIFAR-10 Batch 1:  Cost :0.34003, Accuracy on Training 0.8750 -Validation Accuracy: 0.5508
# Epoch 96, CIFAR-10 Batch 1:  Cost :0.34034, Accuracy on Training 0.9000 -Validation Accuracy: 0.5456
# Epoch 97, CIFAR-10 Batch 1:  Cost :0.33623, Accuracy on Training 0.8750 -Validation Accuracy: 0.5470
# Epoch 98, CIFAR-10 Batch 1:  Cost :0.34336, Accuracy on Training 0.8750 -Validation Accuracy: 0.5442
# Epoch 99, CIFAR-10 Batch 1:  Cost :0.32603, Accuracy on Training 0.9000 -Validation Accuracy: 0.5454
# Epoch 100, CIFAR-10 Batch 1:  Cost :0.32749, Accuracy on Training 0.9000 -Validation Accuracy: 0.5426

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Cost :2.28604, Accuracy on Training 0.2000 -Validation Accuracy: 0.1276
# Epoch  1, CIFAR-10 Batch 2:  Cost :2.28915, Accuracy on Training 0.1250 -Validation Accuracy: 0.1432
# Epoch  1, CIFAR-10 Batch 3:  Cost :2.25629, Accuracy on Training 0.1500 -Validation Accuracy: 0.1522
# Epoch  1, CIFAR-10 Batch 4:  Cost :2.22805, Accuracy on Training 0.1750 -Validation Accuracy: 0.1744
# Epoch  1, CIFAR-10 Batch 5:  Cost :2.14481, Accuracy on Training 0.1750 -Validation Accuracy: 0.1996
# Epoch  2, CIFAR-10 Batch 1:  Cost :2.09707, Accuracy on Training 0.2250 -Validation Accuracy: 0.2232
# Epoch  2, CIFAR-10 Batch 2:  Cost :1.95556, Accuracy on Training 0.3000 -Validation Accuracy: 0.2614
# Epoch  2, CIFAR-10 Batch 3:  Cost :1.83487, Accuracy on Training 0.4250 -Validation Accuracy: 0.2650
# Epoch  2, CIFAR-10 Batch 4:  Cost :1.87892, Accuracy on Training 0.2000 -Validation Accuracy: 0.2970
# Epoch  2, CIFAR-10 Batch 5:  Cost :1.81459, Accuracy on Training 0.4000 -Validation Accuracy: 0.2850
# Epoch  3, CIFAR-10 Batch 1:  Cost :1.95419, Accuracy on Training 0.2750 -Validation Accuracy: 0.2718
# Epoch  3, CIFAR-10 Batch 2:  Cost :1.94923, Accuracy on Training 0.1750 -Validation Accuracy: 0.2576
# Epoch  3, CIFAR-10 Batch 3:  Cost :1.66424, Accuracy on Training 0.4000 -Validation Accuracy: 0.3002
# Epoch  3, CIFAR-10 Batch 4:  Cost :1.75059, Accuracy on Training 0.3000 -Validation Accuracy: 0.3062
# Epoch  3, CIFAR-10 Batch 5:  Cost :1.66635, Accuracy on Training 0.4750 -Validation Accuracy: 0.3154
# Epoch  4, CIFAR-10 Batch 1:  Cost :1.91567, Accuracy on Training 0.2250 -Validation Accuracy: 0.3178
# Epoch  4, CIFAR-10 Batch 2:  Cost :1.82939, Accuracy on Training 0.3750 -Validation Accuracy: 0.3330
# Epoch  4, CIFAR-10 Batch 3:  Cost :1.61419, Accuracy on Training 0.3750 -Validation Accuracy: 0.3292
# Epoch  4, CIFAR-10 Batch 4:  Cost :1.72542, Accuracy on Training 0.3500 -Validation Accuracy: 0.3494
# Epoch  4, CIFAR-10 Batch 5:  Cost :1.62505, Accuracy on Training 0.4750 -Validation Accuracy: 0.3366
# Epoch  5, CIFAR-10 Batch 1:  Cost :1.87627, Accuracy on Training 0.3500 -Validation Accuracy: 0.3484
# Epoch  5, CIFAR-10 Batch 2:  Cost :1.77769, Accuracy on Training 0.3500 -Validation Accuracy: 0.3718
# Epoch  5, CIFAR-10 Batch 3:  Cost :1.50329, Accuracy on Training 0.4750 -Validation Accuracy: 0.3746
# Epoch  5, CIFAR-10 Batch 4:  Cost :1.63317, Accuracy on Training 0.3250 -Validation Accuracy: 0.3646
# Epoch  5, CIFAR-10 Batch 5:  Cost :1.51372, Accuracy on Training 0.5000 -Validation Accuracy: 0.3886
# Epoch  6, CIFAR-10 Batch 1:  Cost :1.73566, Accuracy on Training 0.2750 -Validation Accuracy: 0.3998
# Epoch  6, CIFAR-10 Batch 2:  Cost :1.75097, Accuracy on Training 0.3750 -Validation Accuracy: 0.3996
# Epoch  6, CIFAR-10 Batch 3:  Cost :1.41619, Accuracy on Training 0.4750 -Validation Accuracy: 0.4086
# Epoch  6, CIFAR-10 Batch 4:  Cost :1.59218, Accuracy on Training 0.3500 -Validation Accuracy: 0.4150
# Epoch  6, CIFAR-10 Batch 5:  Cost :1.46818, Accuracy on Training 0.5000 -Validation Accuracy: 0.4124
# Epoch  7, CIFAR-10 Batch 1:  Cost :1.65257, Accuracy on Training 0.4000 -Validation Accuracy: 0.4312
# Epoch  7, CIFAR-10 Batch 2:  Cost :1.69126, Accuracy on Training 0.4750 -Validation Accuracy: 0.4282
# Epoch  7, CIFAR-10 Batch 3:  Cost :1.33489, Accuracy on Training 0.6000 -Validation Accuracy: 0.4354
# Epoch  7, CIFAR-10 Batch 4:  Cost :1.57592, Accuracy on Training 0.3500 -Validation Accuracy: 0.4368
# Epoch  7, CIFAR-10 Batch 5:  Cost :1.46783, Accuracy on Training 0.4750 -Validation Accuracy: 0.4388
# Epoch  8, CIFAR-10 Batch 1:  Cost :1.61739, Accuracy on Training 0.4000 -Validation Accuracy: 0.4516
# Epoch  8, CIFAR-10 Batch 2:  Cost :1.58970, Accuracy on Training 0.4500 -Validation Accuracy: 0.4238
# Epoch  8, CIFAR-10 Batch 3:  Cost :1.27155, Accuracy on Training 0.5000 -Validation Accuracy: 0.4506
# Epoch  8, CIFAR-10 Batch 4:  Cost :1.48822, Accuracy on Training 0.3250 -Validation Accuracy: 0.4504
# Epoch  8, CIFAR-10 Batch 5:  Cost :1.39897, Accuracy on Training 0.5250 -Validation Accuracy: 0.4590
# Epoch  9, CIFAR-10 Batch 1:  Cost :1.52577, Accuracy on Training 0.4500 -Validation Accuracy: 0.4572
# Epoch  9, CIFAR-10 Batch 2:  Cost :1.53185, Accuracy on Training 0.5000 -Validation Accuracy: 0.4656
# Epoch  9, CIFAR-10 Batch 3:  Cost :1.24459, Accuracy on Training 0.6500 -Validation Accuracy: 0.4668
# Epoch  9, CIFAR-10 Batch 4:  Cost :1.45446, Accuracy on Training 0.3750 -Validation Accuracy: 0.4754
# Epoch  9, CIFAR-10 Batch 5:  Cost :1.33347, Accuracy on Training 0.6000 -Validation Accuracy: 0.4824
# Epoch 10, CIFAR-10 Batch 1:  Cost :1.40353, Accuracy on Training 0.4250 -Validation Accuracy: 0.4774
# Epoch 10, CIFAR-10 Batch 2:  Cost :1.44387, Accuracy on Training 0.5250 -Validation Accuracy: 0.4866
# Epoch 10, CIFAR-10 Batch 3:  Cost :1.11113, Accuracy on Training 0.6500 -Validation Accuracy: 0.4892
# Epoch 10, CIFAR-10 Batch 4:  Cost :1.43131, Accuracy on Training 0.4250 -Validation Accuracy: 0.4768
# Epoch 10, CIFAR-10 Batch 5:  Cost :1.25277, Accuracy on Training 0.6250 -Validation Accuracy: 0.4918
# Epoch 11, CIFAR-10 Batch 1:  Cost :1.38944, Accuracy on Training 0.4000 -Validation Accuracy: 0.4836
# Epoch 11, CIFAR-10 Batch 2:  Cost :1.33236, Accuracy on Training 0.5000 -Validation Accuracy: 0.4938
# Epoch 11, CIFAR-10 Batch 3:  Cost :1.07977, Accuracy on Training 0.6250 -Validation Accuracy: 0.5050
# Epoch 11, CIFAR-10 Batch 4:  Cost :1.29486, Accuracy on Training 0.3750 -Validation Accuracy: 0.5094
# Epoch 11, CIFAR-10 Batch 5:  Cost :1.16901, Accuracy on Training 0.6500 -Validation Accuracy: 0.5098
# Epoch 12, CIFAR-10 Batch 1:  Cost :1.34489, Accuracy on Training 0.5000 -Validation Accuracy: 0.4836
# Epoch 12, CIFAR-10 Batch 2:  Cost :1.20856, Accuracy on Training 0.5500 -Validation Accuracy: 0.5084
# Epoch 12, CIFAR-10 Batch 3:  Cost :1.02972, Accuracy on Training 0.6750 -Validation Accuracy: 0.5244
# Epoch 12, CIFAR-10 Batch 4:  Cost :1.25631, Accuracy on Training 0.4250 -Validation Accuracy: 0.5324
# Epoch 12, CIFAR-10 Batch 5:  Cost :1.12165, Accuracy on Training 0.7000 -Validation Accuracy: 0.5240
# Epoch 13, CIFAR-10 Batch 1:  Cost :1.30172, Accuracy on Training 0.5500 -Validation Accuracy: 0.5134
# Epoch 13, CIFAR-10 Batch 2:  Cost :1.15895, Accuracy on Training 0.5500 -Validation Accuracy: 0.5232
# Epoch 13, CIFAR-10 Batch 3:  Cost :1.00872, Accuracy on Training 0.7000 -Validation Accuracy: 0.5366
# Epoch 13, CIFAR-10 Batch 4:  Cost :1.25824, Accuracy on Training 0.4500 -Validation Accuracy: 0.5314
# Epoch 13, CIFAR-10 Batch 5:  Cost :1.08550, Accuracy on Training 0.7000 -Validation Accuracy: 0.5310
# Epoch 14, CIFAR-10 Batch 1:  Cost :1.20438, Accuracy on Training 0.6250 -Validation Accuracy: 0.5272
# Epoch 14, CIFAR-10 Batch 2:  Cost :1.07045, Accuracy on Training 0.5500 -Validation Accuracy: 0.5336
# Epoch 14, CIFAR-10 Batch 3:  Cost :0.95507, Accuracy on Training 0.6500 -Validation Accuracy: 0.5464
# Epoch 14, CIFAR-10 Batch 4:  Cost :1.24902, Accuracy on Training 0.5750 -Validation Accuracy: 0.5446
# Epoch 14, CIFAR-10 Batch 5:  Cost :1.03374, Accuracy on Training 0.7500 -Validation Accuracy: 0.5492
# Epoch 15, CIFAR-10 Batch 1:  Cost :1.10155, Accuracy on Training 0.6000 -Validation Accuracy: 0.5376
# Epoch 15, CIFAR-10 Batch 2:  Cost :1.04016, Accuracy on Training 0.5750 -Validation Accuracy: 0.5484
# Epoch 15, CIFAR-10 Batch 3:  Cost :0.96192, Accuracy on Training 0.7000 -Validation Accuracy: 0.5420
# Epoch 15, CIFAR-10 Batch 4:  Cost :1.15359, Accuracy on Training 0.6250 -Validation Accuracy: 0.5550
# Epoch 15, CIFAR-10 Batch 5:  Cost :1.00752, Accuracy on Training 0.7750 -Validation Accuracy: 0.5658
# Epoch 16, CIFAR-10 Batch 1:  Cost :1.13318, Accuracy on Training 0.6250 -Validation Accuracy: 0.5438
# Epoch 16, CIFAR-10 Batch 2:  Cost :1.01417, Accuracy on Training 0.5250 -Validation Accuracy: 0.5620
# Epoch 16, CIFAR-10 Batch 3:  Cost :0.91375, Accuracy on Training 0.6750 -Validation Accuracy: 0.5558
# Epoch 16, CIFAR-10 Batch 4:  Cost :1.02660, Accuracy on Training 0.7500 -Validation Accuracy: 0.5666
# Epoch 16, CIFAR-10 Batch 5:  Cost :0.95800, Accuracy on Training 0.8000 -Validation Accuracy: 0.5596
# Epoch 17, CIFAR-10 Batch 1:  Cost :1.00524, Accuracy on Training 0.6750 -Validation Accuracy: 0.5664
# Epoch 17, CIFAR-10 Batch 2:  Cost :0.95305, Accuracy on Training 0.6000 -Validation Accuracy: 0.5704
# Epoch 17, CIFAR-10 Batch 3:  Cost :0.86335, Accuracy on Training 0.6750 -Validation Accuracy: 0.5596
# Epoch 17, CIFAR-10 Batch 4:  Cost :0.98875, Accuracy on Training 0.6750 -Validation Accuracy: 0.5766
# Epoch 17, CIFAR-10 Batch 5:  Cost :0.95740, Accuracy on Training 0.8000 -Validation Accuracy: 0.5644
# Epoch 18, CIFAR-10 Batch 1:  Cost :1.01815, Accuracy on Training 0.6250 -Validation Accuracy: 0.5748
# Epoch 18, CIFAR-10 Batch 2:  Cost :0.92308, Accuracy on Training 0.6500 -Validation Accuracy: 0.5736
# Epoch 18, CIFAR-10 Batch 3:  Cost :0.84597, Accuracy on Training 0.7000 -Validation Accuracy: 0.5724
# Epoch 18, CIFAR-10 Batch 4:  Cost :0.96164, Accuracy on Training 0.7750 -Validation Accuracy: 0.5792
# Epoch 18, CIFAR-10 Batch 5:  Cost :0.85615, Accuracy on Training 0.7500 -Validation Accuracy: 0.5790
# Epoch 19, CIFAR-10 Batch 1:  Cost :0.94204, Accuracy on Training 0.7250 -Validation Accuracy: 0.5700
# Epoch 19, CIFAR-10 Batch 2:  Cost :0.91431, Accuracy on Training 0.6000 -Validation Accuracy: 0.5790
# Epoch 19, CIFAR-10 Batch 3:  Cost :0.80235, Accuracy on Training 0.8000 -Validation Accuracy: 0.5768
# Epoch 19, CIFAR-10 Batch 4:  Cost :0.95787, Accuracy on Training 0.8250 -Validation Accuracy: 0.5868
# Epoch 19, CIFAR-10 Batch 5:  Cost :0.85731, Accuracy on Training 0.7750 -Validation Accuracy: 0.5798
# Epoch 20, CIFAR-10 Batch 1:  Cost :0.92535, Accuracy on Training 0.7250 -Validation Accuracy: 0.5862
# Epoch 20, CIFAR-10 Batch 2:  Cost :0.77627, Accuracy on Training 0.7250 -Validation Accuracy: 0.5890
# Epoch 20, CIFAR-10 Batch 3:  Cost :0.73726, Accuracy on Training 0.8250 -Validation Accuracy: 0.5896
# Epoch 20, CIFAR-10 Batch 4:  Cost :0.86738, Accuracy on Training 0.7750 -Validation Accuracy: 0.5984
# Epoch 20, CIFAR-10 Batch 5:  Cost :0.84424, Accuracy on Training 0.8250 -Validation Accuracy: 0.5764
# Epoch 21, CIFAR-10 Batch 1:  Cost :0.94350, Accuracy on Training 0.6750 -Validation Accuracy: 0.5758
# Epoch 21, CIFAR-10 Batch 2:  Cost :0.78080, Accuracy on Training 0.6750 -Validation Accuracy: 0.5880
# Epoch 21, CIFAR-10 Batch 3:  Cost :0.75010, Accuracy on Training 0.7250 -Validation Accuracy: 0.5998
# Epoch 21, CIFAR-10 Batch 4:  Cost :0.86678, Accuracy on Training 0.7250 -Validation Accuracy: 0.5906
# Epoch 21, CIFAR-10 Batch 5:  Cost :0.78856, Accuracy on Training 0.8000 -Validation Accuracy: 0.5816
# Epoch 22, CIFAR-10 Batch 1:  Cost :0.84952, Accuracy on Training 0.7000 -Validation Accuracy: 0.5944
# Epoch 22, CIFAR-10 Batch 2:  Cost :0.73926, Accuracy on Training 0.7000 -Validation Accuracy: 0.5974
# Epoch 22, CIFAR-10 Batch 3:  Cost :0.70515, Accuracy on Training 0.7750 -Validation Accuracy: 0.6018
# Epoch 22, CIFAR-10 Batch 4:  Cost :0.83265, Accuracy on Training 0.8000 -Validation Accuracy: 0.6020
# Epoch 22, CIFAR-10 Batch 5:  Cost :0.77655, Accuracy on Training 0.8000 -Validation Accuracy: 0.5870
# Epoch 23, CIFAR-10 Batch 1:  Cost :0.84758, Accuracy on Training 0.7500 -Validation Accuracy: 0.5962
# Epoch 23, CIFAR-10 Batch 2:  Cost :0.67948, Accuracy on Training 0.7750 -Validation Accuracy: 0.6164
# Epoch 23, CIFAR-10 Batch 3:  Cost :0.68654, Accuracy on Training 0.8000 -Validation Accuracy: 0.6102
# Epoch 23, CIFAR-10 Batch 4:  Cost :0.78135, Accuracy on Training 0.7500 -Validation Accuracy: 0.6110
# Epoch 23, CIFAR-10 Batch 5:  Cost :0.77388, Accuracy on Training 0.8250 -Validation Accuracy: 0.5992
# Epoch 24, CIFAR-10 Batch 1:  Cost :0.83102, Accuracy on Training 0.7250 -Validation Accuracy: 0.6042
# Epoch 24, CIFAR-10 Batch 2:  Cost :0.67006, Accuracy on Training 0.7250 -Validation Accuracy: 0.6118
# Epoch 24, CIFAR-10 Batch 3:  Cost :0.68481, Accuracy on Training 0.7750 -Validation Accuracy: 0.6126
# Epoch 24, CIFAR-10 Batch 4:  Cost :0.77417, Accuracy on Training 0.8000 -Validation Accuracy: 0.6112
# Epoch 24, CIFAR-10 Batch 5:  Cost :0.72191, Accuracy on Training 0.8500 -Validation Accuracy: 0.5998
# Epoch 25, CIFAR-10 Batch 1:  Cost :0.82614, Accuracy on Training 0.6750 -Validation Accuracy: 0.6032
# Epoch 25, CIFAR-10 Batch 2:  Cost :0.64426, Accuracy on Training 0.7750 -Validation Accuracy: 0.6082
# Epoch 25, CIFAR-10 Batch 3:  Cost :0.65037, Accuracy on Training 0.8250 -Validation Accuracy: 0.6054
# Epoch 25, CIFAR-10 Batch 4:  Cost :0.76786, Accuracy on Training 0.7500 -Validation Accuracy: 0.6116
# Epoch 25, CIFAR-10 Batch 5:  Cost :0.73779, Accuracy on Training 0.8250 -Validation Accuracy: 0.6104
# Epoch 26, CIFAR-10 Batch 1:  Cost :0.77578, Accuracy on Training 0.7500 -Validation Accuracy: 0.6028
# Epoch 26, CIFAR-10 Batch 2:  Cost :0.63936, Accuracy on Training 0.8250 -Validation Accuracy: 0.6196
# Epoch 26, CIFAR-10 Batch 3:  Cost :0.62291, Accuracy on Training 0.7500 -Validation Accuracy: 0.6188
# Epoch 26, CIFAR-10 Batch 4:  Cost :0.71302, Accuracy on Training 0.8000 -Validation Accuracy: 0.6202
# Epoch 26, CIFAR-10 Batch 5:  Cost :0.66590, Accuracy on Training 0.8500 -Validation Accuracy: 0.6194
# Epoch 27, CIFAR-10 Batch 1:  Cost :0.72849, Accuracy on Training 0.7500 -Validation Accuracy: 0.5962
# Epoch 27, CIFAR-10 Batch 2:  Cost :0.60986, Accuracy on Training 0.7750 -Validation Accuracy: 0.6180
# Epoch 27, CIFAR-10 Batch 3:  Cost :0.65280, Accuracy on Training 0.7750 -Validation Accuracy: 0.6096
# Epoch 27, CIFAR-10 Batch 4:  Cost :0.70055, Accuracy on Training 0.8500 -Validation Accuracy: 0.6204
# Epoch 27, CIFAR-10 Batch 5:  Cost :0.67242, Accuracy on Training 0.7500 -Validation Accuracy: 0.6116
# Epoch 28, CIFAR-10 Batch 1:  Cost :0.76576, Accuracy on Training 0.7500 -Validation Accuracy: 0.6054
# Epoch 28, CIFAR-10 Batch 2:  Cost :0.57909, Accuracy on Training 0.8250 -Validation Accuracy: 0.6176
# Epoch 28, CIFAR-10 Batch 3:  Cost :0.59957, Accuracy on Training 0.8250 -Validation Accuracy: 0.6244
# Epoch 28, CIFAR-10 Batch 4:  Cost :0.67868, Accuracy on Training 0.8250 -Validation Accuracy: 0.6252
# Epoch 28, CIFAR-10 Batch 5:  Cost :0.63134, Accuracy on Training 0.8250 -Validation Accuracy: 0.6128
# Epoch 29, CIFAR-10 Batch 1:  Cost :0.70830, Accuracy on Training 0.7000 -Validation Accuracy: 0.6074
# Epoch 29, CIFAR-10 Batch 2:  Cost :0.54973, Accuracy on Training 0.8250 -Validation Accuracy: 0.6242
# Epoch 29, CIFAR-10 Batch 3:  Cost :0.55665, Accuracy on Training 0.8000 -Validation Accuracy: 0.6206
# Epoch 29, CIFAR-10 Batch 4:  Cost :0.63755, Accuracy on Training 0.8250 -Validation Accuracy: 0.6306
# Epoch 29, CIFAR-10 Batch 5:  Cost :0.63420, Accuracy on Training 0.9000 -Validation Accuracy: 0.6258
# Epoch 30, CIFAR-10 Batch 1:  Cost :0.66266, Accuracy on Training 0.7500 -Validation Accuracy: 0.6298
# Epoch 30, CIFAR-10 Batch 2:  Cost :0.53297, Accuracy on Training 0.8250 -Validation Accuracy: 0.6280
# Epoch 30, CIFAR-10 Batch 3:  Cost :0.54334, Accuracy on Training 0.8250 -Validation Accuracy: 0.6286
# Epoch 30, CIFAR-10 Batch 4:  Cost :0.63531, Accuracy on Training 0.8750 -Validation Accuracy: 0.6314
# Epoch 30, CIFAR-10 Batch 5:  Cost :0.65621, Accuracy on Training 0.8500 -Validation Accuracy: 0.6232
# Epoch 31, CIFAR-10 Batch 1:  Cost :0.65854, Accuracy on Training 0.7500 -Validation Accuracy: 0.6176
# Epoch 31, CIFAR-10 Batch 2:  Cost :0.53927, Accuracy on Training 0.8250 -Validation Accuracy: 0.6274
# Epoch 31, CIFAR-10 Batch 3:  Cost :0.52130, Accuracy on Training 0.8500 -Validation Accuracy: 0.6356
# Epoch 31, CIFAR-10 Batch 4:  Cost :0.61185, Accuracy on Training 0.8250 -Validation Accuracy: 0.6374
# Epoch 31, CIFAR-10 Batch 5:  Cost :0.59125, Accuracy on Training 0.9000 -Validation Accuracy: 0.6158
# Epoch 32, CIFAR-10 Batch 1:  Cost :0.63299, Accuracy on Training 0.7500 -Validation Accuracy: 0.6236
# Epoch 32, CIFAR-10 Batch 2:  Cost :0.55752, Accuracy on Training 0.8500 -Validation Accuracy: 0.6308
# Epoch 32, CIFAR-10 Batch 3:  Cost :0.52774, Accuracy on Training 0.8250 -Validation Accuracy: 0.6346
# Epoch 32, CIFAR-10 Batch 4:  Cost :0.60736, Accuracy on Training 0.8500 -Validation Accuracy: 0.6372
# Epoch 32, CIFAR-10 Batch 5:  Cost :0.55988, Accuracy on Training 0.8750 -Validation Accuracy: 0.6290
# Epoch 33, CIFAR-10 Batch 1:  Cost :0.63835, Accuracy on Training 0.7250 -Validation Accuracy: 0.6292
# Epoch 33, CIFAR-10 Batch 2:  Cost :0.52090, Accuracy on Training 0.8250 -Validation Accuracy: 0.6400
# Epoch 33, CIFAR-10 Batch 3:  Cost :0.53120, Accuracy on Training 0.8000 -Validation Accuracy: 0.6330
# Epoch 33, CIFAR-10 Batch 4:  Cost :0.57476, Accuracy on Training 0.8750 -Validation Accuracy: 0.6352
# Epoch 33, CIFAR-10 Batch 5:  Cost :0.57291, Accuracy on Training 0.8750 -Validation Accuracy: 0.6394
# Epoch 34, CIFAR-10 Batch 1:  Cost :0.62108, Accuracy on Training 0.7500 -Validation Accuracy: 0.6358
# Epoch 34, CIFAR-10 Batch 2:  Cost :0.53566, Accuracy on Training 0.8500 -Validation Accuracy: 0.6308
# Epoch 34, CIFAR-10 Batch 3:  Cost :0.50442, Accuracy on Training 0.8500 -Validation Accuracy: 0.6376
# Epoch 34, CIFAR-10 Batch 4:  Cost :0.55096, Accuracy on Training 0.8500 -Validation Accuracy: 0.6408
# Epoch 34, CIFAR-10 Batch 5:  Cost :0.56558, Accuracy on Training 0.9250 -Validation Accuracy: 0.6342
# Epoch 35, CIFAR-10 Batch 1:  Cost :0.62502, Accuracy on Training 0.8250 -Validation Accuracy: 0.6282
# Epoch 35, CIFAR-10 Batch 2:  Cost :0.50391, Accuracy on Training 0.8500 -Validation Accuracy: 0.6382
# Epoch 35, CIFAR-10 Batch 3:  Cost :0.52405, Accuracy on Training 0.8500 -Validation Accuracy: 0.6368
# Epoch 35, CIFAR-10 Batch 4:  Cost :0.55169, Accuracy on Training 0.9000 -Validation Accuracy: 0.6386
# Epoch 35, CIFAR-10 Batch 5:  Cost :0.57660, Accuracy on Training 0.9000 -Validation Accuracy: 0.6364
# Epoch 36, CIFAR-10 Batch 1:  Cost :0.60006, Accuracy on Training 0.7500 -Validation Accuracy: 0.6390
# Epoch 36, CIFAR-10 Batch 2:  Cost :0.47809, Accuracy on Training 0.8500 -Validation Accuracy: 0.6396
# Epoch 36, CIFAR-10 Batch 3:  Cost :0.46733, Accuracy on Training 0.8250 -Validation Accuracy: 0.6474
# Epoch 36, CIFAR-10 Batch 4:  Cost :0.51283, Accuracy on Training 0.9250 -Validation Accuracy: 0.6470
# Epoch 36, CIFAR-10 Batch 5:  Cost :0.52735, Accuracy on Training 0.9250 -Validation Accuracy: 0.6234
# Epoch 37, CIFAR-10 Batch 1:  Cost :0.56695, Accuracy on Training 0.7750 -Validation Accuracy: 0.6262
# Epoch 37, CIFAR-10 Batch 2:  Cost :0.47908, Accuracy on Training 0.8250 -Validation Accuracy: 0.6422
# Epoch 37, CIFAR-10 Batch 3:  Cost :0.47813, Accuracy on Training 0.8250 -Validation Accuracy: 0.6472
# Epoch 37, CIFAR-10 Batch 4:  Cost :0.48237, Accuracy on Training 0.9000 -Validation Accuracy: 0.6348
# Epoch 37, CIFAR-10 Batch 5:  Cost :0.51819, Accuracy on Training 0.9500 -Validation Accuracy: 0.6442
# Epoch 38, CIFAR-10 Batch 1:  Cost :0.58141, Accuracy on Training 0.7750 -Validation Accuracy: 0.6346
# Epoch 38, CIFAR-10 Batch 2:  Cost :0.44453, Accuracy on Training 0.8250 -Validation Accuracy: 0.6422
# Epoch 38, CIFAR-10 Batch 3:  Cost :0.43787, Accuracy on Training 0.8500 -Validation Accuracy: 0.6472
# Epoch 38, CIFAR-10 Batch 4:  Cost :0.49549, Accuracy on Training 0.9250 -Validation Accuracy: 0.6474
# Epoch 38, CIFAR-10 Batch 5:  Cost :0.52137, Accuracy on Training 0.9250 -Validation Accuracy: 0.6342
# Epoch 39, CIFAR-10 Batch 1:  Cost :0.56231, Accuracy on Training 0.7750 -Validation Accuracy: 0.6402
# Epoch 39, CIFAR-10 Batch 2:  Cost :0.52027, Accuracy on Training 0.8250 -Validation Accuracy: 0.6428
# Epoch 39, CIFAR-10 Batch 3:  Cost :0.44882, Accuracy on Training 0.8750 -Validation Accuracy: 0.6416
# Epoch 39, CIFAR-10 Batch 4:  Cost :0.48170, Accuracy on Training 0.9500 -Validation Accuracy: 0.6420
# Epoch 39, CIFAR-10 Batch 5:  Cost :0.51636, Accuracy on Training 0.9000 -Validation Accuracy: 0.6456
# Epoch 40, CIFAR-10 Batch 1:  Cost :0.55375, Accuracy on Training 0.7750 -Validation Accuracy: 0.6482
# Epoch 40, CIFAR-10 Batch 2:  Cost :0.45944, Accuracy on Training 0.8250 -Validation Accuracy: 0.6330
# Epoch 40, CIFAR-10 Batch 3:  Cost :0.42971, Accuracy on Training 0.9000 -Validation Accuracy: 0.6540
# Epoch 40, CIFAR-10 Batch 4:  Cost :0.44262, Accuracy on Training 0.9250 -Validation Accuracy: 0.6496
# Epoch 40, CIFAR-10 Batch 5:  Cost :0.50297, Accuracy on Training 0.9000 -Validation Accuracy: 0.6418
# Epoch 41, CIFAR-10 Batch 1:  Cost :0.54722, Accuracy on Training 0.7750 -Validation Accuracy: 0.6348
# Epoch 41, CIFAR-10 Batch 2:  Cost :0.43271, Accuracy on Training 0.8500 -Validation Accuracy: 0.6466
# Epoch 41, CIFAR-10 Batch 3:  Cost :0.46127, Accuracy on Training 0.8750 -Validation Accuracy: 0.6440
# Epoch 41, CIFAR-10 Batch 4:  Cost :0.43853, Accuracy on Training 0.9000 -Validation Accuracy: 0.6420
# Epoch 41, CIFAR-10 Batch 5:  Cost :0.47967, Accuracy on Training 0.8500 -Validation Accuracy: 0.6478
# Epoch 42, CIFAR-10 Batch 1:  Cost :0.55454, Accuracy on Training 0.7750 -Validation Accuracy: 0.6266
# Epoch 42, CIFAR-10 Batch 2:  Cost :0.43956, Accuracy on Training 0.8750 -Validation Accuracy: 0.6478
# Epoch 42, CIFAR-10 Batch 3:  Cost :0.42695, Accuracy on Training 0.8500 -Validation Accuracy: 0.6386
# Epoch 42, CIFAR-10 Batch 4:  Cost :0.44753, Accuracy on Training 0.9250 -Validation Accuracy: 0.6366
# Epoch 42, CIFAR-10 Batch 5:  Cost :0.46615, Accuracy on Training 0.9250 -Validation Accuracy: 0.6514
# Epoch 43, CIFAR-10 Batch 1:  Cost :0.56805, Accuracy on Training 0.8000 -Validation Accuracy: 0.6226
# Epoch 43, CIFAR-10 Batch 2:  Cost :0.44422, Accuracy on Training 0.8500 -Validation Accuracy: 0.6450
# Epoch 43, CIFAR-10 Batch 3:  Cost :0.41897, Accuracy on Training 0.9000 -Validation Accuracy: 0.6426
# Epoch 43, CIFAR-10 Batch 4:  Cost :0.42193, Accuracy on Training 0.9250 -Validation Accuracy: 0.6486
# Epoch 43, CIFAR-10 Batch 5:  Cost :0.46523, Accuracy on Training 0.9500 -Validation Accuracy: 0.6424
# Epoch 44, CIFAR-10 Batch 1:  Cost :0.51100, Accuracy on Training 0.8000 -Validation Accuracy: 0.6480
# Epoch 44, CIFAR-10 Batch 2:  Cost :0.41050, Accuracy on Training 0.8750 -Validation Accuracy: 0.6590
# Epoch 44, CIFAR-10 Batch 3:  Cost :0.39417, Accuracy on Training 0.9250 -Validation Accuracy: 0.6502
# Epoch 44, CIFAR-10 Batch 4:  Cost :0.42765, Accuracy on Training 0.9250 -Validation Accuracy: 0.6354
# Epoch 44, CIFAR-10 Batch 5:  Cost :0.47062, Accuracy on Training 0.9000 -Validation Accuracy: 0.6404
# Epoch 45, CIFAR-10 Batch 1:  Cost :0.53699, Accuracy on Training 0.7750 -Validation Accuracy: 0.6400
# Epoch 45, CIFAR-10 Batch 2:  Cost :0.41396, Accuracy on Training 0.9000 -Validation Accuracy: 0.6424
# Epoch 45, CIFAR-10 Batch 3:  Cost :0.40403, Accuracy on Training 0.9000 -Validation Accuracy: 0.6596
# Epoch 45, CIFAR-10 Batch 4:  Cost :0.44809, Accuracy on Training 0.9250 -Validation Accuracy: 0.6508
# Epoch 45, CIFAR-10 Batch 5:  Cost :0.44639, Accuracy on Training 0.9000 -Validation Accuracy: 0.6318
# Epoch 46, CIFAR-10 Batch 1:  Cost :0.48307, Accuracy on Training 0.8250 -Validation Accuracy: 0.6512
# Epoch 46, CIFAR-10 Batch 2:  Cost :0.44498, Accuracy on Training 0.8500 -Validation Accuracy: 0.6430
# Epoch 46, CIFAR-10 Batch 3:  Cost :0.38405, Accuracy on Training 0.9000 -Validation Accuracy: 0.6544
# Epoch 46, CIFAR-10 Batch 4:  Cost :0.41381, Accuracy on Training 0.9000 -Validation Accuracy: 0.6566
# Epoch 46, CIFAR-10 Batch 5:  Cost :0.44462, Accuracy on Training 0.8750 -Validation Accuracy: 0.6424
# Epoch 47, CIFAR-10 Batch 1:  Cost :0.48250, Accuracy on Training 0.8250 -Validation Accuracy: 0.6440
# Epoch 47, CIFAR-10 Batch 2:  Cost :0.43607, Accuracy on Training 0.8500 -Validation Accuracy: 0.6558
# Epoch 47, CIFAR-10 Batch 3:  Cost :0.39277, Accuracy on Training 0.9250 -Validation Accuracy: 0.6534
# Epoch 47, CIFAR-10 Batch 4:  Cost :0.43553, Accuracy on Training 0.9250 -Validation Accuracy: 0.6538
# Epoch 47, CIFAR-10 Batch 5:  Cost :0.39942, Accuracy on Training 0.9250 -Validation Accuracy: 0.6478
# Epoch 48, CIFAR-10 Batch 1:  Cost :0.51640, Accuracy on Training 0.8250 -Validation Accuracy: 0.6378
# Epoch 48, CIFAR-10 Batch 2:  Cost :0.41664, Accuracy on Training 0.9250 -Validation Accuracy: 0.6514
# Epoch 48, CIFAR-10 Batch 3:  Cost :0.35797, Accuracy on Training 0.9000 -Validation Accuracy: 0.6634
# Epoch 48, CIFAR-10 Batch 4:  Cost :0.40934, Accuracy on Training 0.9250 -Validation Accuracy: 0.6530
# Epoch 48, CIFAR-10 Batch 5:  Cost :0.39917, Accuracy on Training 0.9250 -Validation Accuracy: 0.6474
# Epoch 49, CIFAR-10 Batch 1:  Cost :0.48766, Accuracy on Training 0.8250 -Validation Accuracy: 0.6550
# Epoch 49, CIFAR-10 Batch 2:  Cost :0.41418, Accuracy on Training 0.8500 -Validation Accuracy: 0.6552
# Epoch 49, CIFAR-10 Batch 3:  Cost :0.32725, Accuracy on Training 0.9250 -Validation Accuracy: 0.6644
# Epoch 49, CIFAR-10 Batch 4:  Cost :0.41523, Accuracy on Training 0.9250 -Validation Accuracy: 0.6618
# Epoch 49, CIFAR-10 Batch 5:  Cost :0.38758, Accuracy on Training 0.9250 -Validation Accuracy: 0.6572
# Epoch 50, CIFAR-10 Batch 1:  Cost :0.47797, Accuracy on Training 0.8250 -Validation Accuracy: 0.6504
# Epoch 50, CIFAR-10 Batch 2:  Cost :0.38801, Accuracy on Training 0.8750 -Validation Accuracy: 0.6652
# Epoch 50, CIFAR-10 Batch 3:  Cost :0.35854, Accuracy on Training 0.8750 -Validation Accuracy: 0.6642
# Epoch 50, CIFAR-10 Batch 4:  Cost :0.43831, Accuracy on Training 0.9000 -Validation Accuracy: 0.6438
# Epoch 50, CIFAR-10 Batch 5:  Cost :0.41034, Accuracy on Training 0.9000 -Validation Accuracy: 0.6604
# Epoch 51, CIFAR-10 Batch 1:  Cost :0.49657, Accuracy on Training 0.8500 -Validation Accuracy: 0.6388
# Epoch 51, CIFAR-10 Batch 2:  Cost :0.36988, Accuracy on Training 0.8750 -Validation Accuracy: 0.6616
# Epoch 51, CIFAR-10 Batch 3:  Cost :0.33805, Accuracy on Training 0.9000 -Validation Accuracy: 0.6606
# Epoch 51, CIFAR-10 Batch 4:  Cost :0.38624, Accuracy on Training 0.9500 -Validation Accuracy: 0.6534
# Epoch 51, CIFAR-10 Batch 5:  Cost :0.39738, Accuracy on Training 0.9500 -Validation Accuracy: 0.6594
# Epoch 52, CIFAR-10 Batch 1:  Cost :0.41940, Accuracy on Training 0.8750 -Validation Accuracy: 0.6452
# Epoch 52, CIFAR-10 Batch 2:  Cost :0.42200, Accuracy on Training 0.8250 -Validation Accuracy: 0.6562
# Epoch 52, CIFAR-10 Batch 3:  Cost :0.30642, Accuracy on Training 0.9250 -Validation Accuracy: 0.6668
# Epoch 52, CIFAR-10 Batch 4:  Cost :0.40822, Accuracy on Training 0.9250 -Validation Accuracy: 0.6580
# Epoch 52, CIFAR-10 Batch 5:  Cost :0.36677, Accuracy on Training 0.9750 -Validation Accuracy: 0.6710
# Epoch 53, CIFAR-10 Batch 1:  Cost :0.42992, Accuracy on Training 0.8500 -Validation Accuracy: 0.6382
# Epoch 53, CIFAR-10 Batch 2:  Cost :0.37224, Accuracy on Training 0.8750 -Validation Accuracy: 0.6634
# Epoch 53, CIFAR-10 Batch 3:  Cost :0.30381, Accuracy on Training 0.9250 -Validation Accuracy: 0.6706
# Epoch 53, CIFAR-10 Batch 4:  Cost :0.37325, Accuracy on Training 0.9500 -Validation Accuracy: 0.6564
# Epoch 53, CIFAR-10 Batch 5:  Cost :0.35713, Accuracy on Training 0.9750 -Validation Accuracy: 0.6644
# Epoch 54, CIFAR-10 Batch 1:  Cost :0.40978, Accuracy on Training 0.8750 -Validation Accuracy: 0.6500
# Epoch 54, CIFAR-10 Batch 2:  Cost :0.36785, Accuracy on Training 0.9000 -Validation Accuracy: 0.6682
# Epoch 54, CIFAR-10 Batch 3:  Cost :0.29370, Accuracy on Training 0.9250 -Validation Accuracy: 0.6656
# Epoch 54, CIFAR-10 Batch 4:  Cost :0.34935, Accuracy on Training 0.9250 -Validation Accuracy: 0.6624
# Epoch 54, CIFAR-10 Batch 5:  Cost :0.35117, Accuracy on Training 0.9500 -Validation Accuracy: 0.6546
# Epoch 55, CIFAR-10 Batch 1:  Cost :0.39633, Accuracy on Training 0.8750 -Validation Accuracy: 0.6350
# Epoch 55, CIFAR-10 Batch 2:  Cost :0.36250, Accuracy on Training 0.8500 -Validation Accuracy: 0.6632
# Epoch 55, CIFAR-10 Batch 3:  Cost :0.30516, Accuracy on Training 0.9250 -Validation Accuracy: 0.6526
# Epoch 55, CIFAR-10 Batch 4:  Cost :0.37184, Accuracy on Training 0.9250 -Validation Accuracy: 0.6580
# Epoch 55, CIFAR-10 Batch 5:  Cost :0.35941, Accuracy on Training 0.9750 -Validation Accuracy: 0.6488
# Epoch 56, CIFAR-10 Batch 1:  Cost :0.38435, Accuracy on Training 0.9000 -Validation Accuracy: 0.6484
# Epoch 56, CIFAR-10 Batch 2:  Cost :0.38544, Accuracy on Training 0.8500 -Validation Accuracy: 0.6554
# Epoch 56, CIFAR-10 Batch 3:  Cost :0.28166, Accuracy on Training 0.9500 -Validation Accuracy: 0.6698
# Epoch 56, CIFAR-10 Batch 4:  Cost :0.34992, Accuracy on Training 0.9000 -Validation Accuracy: 0.6496
# Epoch 56, CIFAR-10 Batch 5:  Cost :0.36700, Accuracy on Training 0.9250 -Validation Accuracy: 0.6546
# Epoch 57, CIFAR-10 Batch 1:  Cost :0.41783, Accuracy on Training 0.8750 -Validation Accuracy: 0.6442
# Epoch 57, CIFAR-10 Batch 2:  Cost :0.40614, Accuracy on Training 0.8500 -Validation Accuracy: 0.6502
# Epoch 57, CIFAR-10 Batch 3:  Cost :0.31316, Accuracy on Training 0.9500 -Validation Accuracy: 0.6638
# Epoch 57, CIFAR-10 Batch 4:  Cost :0.37440, Accuracy on Training 0.9250 -Validation Accuracy: 0.6636
# Epoch 57, CIFAR-10 Batch 5:  Cost :0.35647, Accuracy on Training 0.9500 -Validation Accuracy: 0.6630
# Epoch 58, CIFAR-10 Batch 1:  Cost :0.43119, Accuracy on Training 0.8750 -Validation Accuracy: 0.6384
# Epoch 58, CIFAR-10 Batch 2:  Cost :0.35936, Accuracy on Training 0.8750 -Validation Accuracy: 0.6648
# Epoch 58, CIFAR-10 Batch 3:  Cost :0.28849, Accuracy on Training 0.9500 -Validation Accuracy: 0.6734
# Epoch 58, CIFAR-10 Batch 4:  Cost :0.36091, Accuracy on Training 0.9500 -Validation Accuracy: 0.6522
# Epoch 58, CIFAR-10 Batch 5:  Cost :0.33852, Accuracy on Training 0.9750 -Validation Accuracy: 0.6606
# Epoch 59, CIFAR-10 Batch 1:  Cost :0.36696, Accuracy on Training 0.9250 -Validation Accuracy: 0.6576
# Epoch 59, CIFAR-10 Batch 2:  Cost :0.40408, Accuracy on Training 0.8500 -Validation Accuracy: 0.6516
# Epoch 59, CIFAR-10 Batch 3:  Cost :0.30484, Accuracy on Training 0.9750 -Validation Accuracy: 0.6660
# Epoch 59, CIFAR-10 Batch 4:  Cost :0.34492, Accuracy on Training 0.9250 -Validation Accuracy: 0.6634
# Epoch 59, CIFAR-10 Batch 5:  Cost :0.34488, Accuracy on Training 0.9750 -Validation Accuracy: 0.6628
# Epoch 60, CIFAR-10 Batch 1:  Cost :0.37935, Accuracy on Training 0.9000 -Validation Accuracy: 0.6522
# Epoch 60, CIFAR-10 Batch 2:  Cost :0.40187, Accuracy on Training 0.8500 -Validation Accuracy: 0.6592
# Epoch 60, CIFAR-10 Batch 3:  Cost :0.28771, Accuracy on Training 0.9500 -Validation Accuracy: 0.6652
# Epoch 60, CIFAR-10 Batch 4:  Cost :0.34082, Accuracy on Training 0.9250 -Validation Accuracy: 0.6500
# Epoch 60, CIFAR-10 Batch 5:  Cost :0.33437, Accuracy on Training 0.9750 -Validation Accuracy: 0.6572
# Epoch 61, CIFAR-10 Batch 1:  Cost :0.38402, Accuracy on Training 0.9000 -Validation Accuracy: 0.6576
# Epoch 61, CIFAR-10 Batch 2:  Cost :0.40396, Accuracy on Training 0.8250 -Validation Accuracy: 0.6638
# Epoch 61, CIFAR-10 Batch 3:  Cost :0.28361, Accuracy on Training 0.9750 -Validation Accuracy: 0.6610
# Epoch 61, CIFAR-10 Batch 4:  Cost :0.32011, Accuracy on Training 0.9500 -Validation Accuracy: 0.6646
# Epoch 61, CIFAR-10 Batch 5:  Cost :0.35415, Accuracy on Training 0.9500 -Validation Accuracy: 0.6510
# Epoch 62, CIFAR-10 Batch 1:  Cost :0.36799, Accuracy on Training 0.9000 -Validation Accuracy: 0.6600
# Epoch 62, CIFAR-10 Batch 2:  Cost :0.35312, Accuracy on Training 0.8750 -Validation Accuracy: 0.6706
# Epoch 62, CIFAR-10 Batch 3:  Cost :0.27217, Accuracy on Training 0.9750 -Validation Accuracy: 0.6604
# Epoch 62, CIFAR-10 Batch 4:  Cost :0.35283, Accuracy on Training 0.9500 -Validation Accuracy: 0.6544
# Epoch 62, CIFAR-10 Batch 5:  Cost :0.32883, Accuracy on Training 0.9750 -Validation Accuracy: 0.6508
# Epoch 63, CIFAR-10 Batch 1:  Cost :0.35713, Accuracy on Training 0.9250 -Validation Accuracy: 0.6508
# Epoch 63, CIFAR-10 Batch 2:  Cost :0.37201, Accuracy on Training 0.8750 -Validation Accuracy: 0.6626
# Epoch 63, CIFAR-10 Batch 3:  Cost :0.24357, Accuracy on Training 0.9250 -Validation Accuracy: 0.6660
# Epoch 63, CIFAR-10 Batch 4:  Cost :0.33840, Accuracy on Training 0.9500 -Validation Accuracy: 0.6586
# Epoch 63, CIFAR-10 Batch 5:  Cost :0.32248, Accuracy on Training 0.9750 -Validation Accuracy: 0.6498
# Epoch 64, CIFAR-10 Batch 1:  Cost :0.34777, Accuracy on Training 0.9250 -Validation Accuracy: 0.6572
# Epoch 64, CIFAR-10 Batch 2:  Cost :0.36733, Accuracy on Training 0.8750 -Validation Accuracy: 0.6578
# Epoch 64, CIFAR-10 Batch 3:  Cost :0.27074, Accuracy on Training 0.9250 -Validation Accuracy: 0.6646
# Epoch 64, CIFAR-10 Batch 4:  Cost :0.30137, Accuracy on Training 0.9500 -Validation Accuracy: 0.6648
# Epoch 64, CIFAR-10 Batch 5:  Cost :0.34501, Accuracy on Training 0.9500 -Validation Accuracy: 0.6570
# Epoch 65, CIFAR-10 Batch 1:  Cost :0.31744, Accuracy on Training 0.9500 -Validation Accuracy: 0.6602
# Epoch 65, CIFAR-10 Batch 2:  Cost :0.35085, Accuracy on Training 0.8750 -Validation Accuracy: 0.6546
# Epoch 65, CIFAR-10 Batch 3:  Cost :0.25333, Accuracy on Training 0.9250 -Validation Accuracy: 0.6678
# Epoch 65, CIFAR-10 Batch 4:  Cost :0.33750, Accuracy on Training 0.9250 -Validation Accuracy: 0.6574
# Epoch 65, CIFAR-10 Batch 5:  Cost :0.34519, Accuracy on Training 0.9250 -Validation Accuracy: 0.6500
# Epoch 66, CIFAR-10 Batch 1:  Cost :0.31098, Accuracy on Training 0.9250 -Validation Accuracy: 0.6544
# Epoch 66, CIFAR-10 Batch 2:  Cost :0.33406, Accuracy on Training 0.8750 -Validation Accuracy: 0.6644
# Epoch 66, CIFAR-10 Batch 3:  Cost :0.27888, Accuracy on Training 0.9750 -Validation Accuracy: 0.6638
# Epoch 66, CIFAR-10 Batch 4:  Cost :0.30123, Accuracy on Training 0.9500 -Validation Accuracy: 0.6664
# Epoch 66, CIFAR-10 Batch 5:  Cost :0.34516, Accuracy on Training 0.9500 -Validation Accuracy: 0.6522
# Epoch 67, CIFAR-10 Batch 1:  Cost :0.30975, Accuracy on Training 0.9000 -Validation Accuracy: 0.6628
# Epoch 67, CIFAR-10 Batch 2:  Cost :0.33777, Accuracy on Training 0.8750 -Validation Accuracy: 0.6650
# Epoch 67, CIFAR-10 Batch 3:  Cost :0.25701, Accuracy on Training 0.9750 -Validation Accuracy: 0.6610
# Epoch 67, CIFAR-10 Batch 4:  Cost :0.31645, Accuracy on Training 0.9500 -Validation Accuracy: 0.6642
# Epoch 67, CIFAR-10 Batch 5:  Cost :0.36888, Accuracy on Training 0.9250 -Validation Accuracy: 0.6506
# Epoch 68, CIFAR-10 Batch 1:  Cost :0.29566, Accuracy on Training 0.9500 -Validation Accuracy: 0.6646
# Epoch 68, CIFAR-10 Batch 2:  Cost :0.32931, Accuracy on Training 0.8750 -Validation Accuracy: 0.6692
# Epoch 68, CIFAR-10 Batch 3:  Cost :0.23167, Accuracy on Training 0.9250 -Validation Accuracy: 0.6742
# Epoch 68, CIFAR-10 Batch 4:  Cost :0.30199, Accuracy on Training 0.9250 -Validation Accuracy: 0.6608
# Epoch 68, CIFAR-10 Batch 5:  Cost :0.35459, Accuracy on Training 0.9500 -Validation Accuracy: 0.6638
# Epoch 69, CIFAR-10 Batch 1:  Cost :0.30827, Accuracy on Training 0.9000 -Validation Accuracy: 0.6644
# Epoch 69, CIFAR-10 Batch 2:  Cost :0.36609, Accuracy on Training 0.8500 -Validation Accuracy: 0.6684
# Epoch 69, CIFAR-10 Batch 3:  Cost :0.24722, Accuracy on Training 0.9250 -Validation Accuracy: 0.6676
# Epoch 69, CIFAR-10 Batch 4:  Cost :0.29550, Accuracy on Training 0.9500 -Validation Accuracy: 0.6614
# Epoch 69, CIFAR-10 Batch 5:  Cost :0.32452, Accuracy on Training 0.9250 -Validation Accuracy: 0.6428
# Epoch 70, CIFAR-10 Batch 1:  Cost :0.28292, Accuracy on Training 0.9250 -Validation Accuracy: 0.6610
# Epoch 70, CIFAR-10 Batch 2:  Cost :0.31365, Accuracy on Training 0.9000 -Validation Accuracy: 0.6648
# Epoch 70, CIFAR-10 Batch 3:  Cost :0.26021, Accuracy on Training 0.9500 -Validation Accuracy: 0.6680
# Epoch 70, CIFAR-10 Batch 4:  Cost :0.32665, Accuracy on Training 0.9250 -Validation Accuracy: 0.6486
# Epoch 70, CIFAR-10 Batch 5:  Cost :0.31289, Accuracy on Training 0.9500 -Validation Accuracy: 0.6610
# Epoch 71, CIFAR-10 Batch 1:  Cost :0.28741, Accuracy on Training 0.9500 -Validation Accuracy: 0.6602
# Epoch 71, CIFAR-10 Batch 2:  Cost :0.34518, Accuracy on Training 0.8500 -Validation Accuracy: 0.6684
# Epoch 71, CIFAR-10 Batch 3:  Cost :0.24439, Accuracy on Training 0.9750 -Validation Accuracy: 0.6712
# Epoch 71, CIFAR-10 Batch 4:  Cost :0.29119, Accuracy on Training 0.9500 -Validation Accuracy: 0.6572
# Epoch 71, CIFAR-10 Batch 5:  Cost :0.30586, Accuracy on Training 0.9500 -Validation Accuracy: 0.6566
# Epoch 72, CIFAR-10 Batch 1:  Cost :0.29420, Accuracy on Training 0.9500 -Validation Accuracy: 0.6734
# Epoch 72, CIFAR-10 Batch 2:  Cost :0.30428, Accuracy on Training 0.9250 -Validation Accuracy: 0.6706
# Epoch 72, CIFAR-10 Batch 3:  Cost :0.24756, Accuracy on Training 0.9250 -Validation Accuracy: 0.6634
# Epoch 72, CIFAR-10 Batch 4:  Cost :0.31245, Accuracy on Training 0.9250 -Validation Accuracy: 0.6560
# Epoch 72, CIFAR-10 Batch 5:  Cost :0.34267, Accuracy on Training 0.9500 -Validation Accuracy: 0.6492
# Epoch 73, CIFAR-10 Batch 1:  Cost :0.31330, Accuracy on Training 0.9250 -Validation Accuracy: 0.6562
# Epoch 73, CIFAR-10 Batch 2:  Cost :0.30693, Accuracy on Training 0.8750 -Validation Accuracy: 0.6728
# Epoch 73, CIFAR-10 Batch 3:  Cost :0.23239, Accuracy on Training 0.9500 -Validation Accuracy: 0.6752
# Epoch 73, CIFAR-10 Batch 4:  Cost :0.31028, Accuracy on Training 0.9250 -Validation Accuracy: 0.6588
# Epoch 73, CIFAR-10 Batch 5:  Cost :0.26158, Accuracy on Training 0.9750 -Validation Accuracy: 0.6646
# Epoch 74, CIFAR-10 Batch 1:  Cost :0.30530, Accuracy on Training 0.9250 -Validation Accuracy: 0.6694
# Epoch 74, CIFAR-10 Batch 2:  Cost :0.29370, Accuracy on Training 0.9500 -Validation Accuracy: 0.6654
# Epoch 74, CIFAR-10 Batch 3:  Cost :0.20897, Accuracy on Training 0.9750 -Validation Accuracy: 0.6700
# Epoch 74, CIFAR-10 Batch 4:  Cost :0.28627, Accuracy on Training 0.9500 -Validation Accuracy: 0.6608
# Epoch 74, CIFAR-10 Batch 5:  Cost :0.25134, Accuracy on Training 0.9750 -Validation Accuracy: 0.6712
# Epoch 75, CIFAR-10 Batch 1:  Cost :0.24926, Accuracy on Training 0.9500 -Validation Accuracy: 0.6690
# Epoch 75, CIFAR-10 Batch 2:  Cost :0.30652, Accuracy on Training 0.9000 -Validation Accuracy: 0.6584
# Epoch 75, CIFAR-10 Batch 3:  Cost :0.21698, Accuracy on Training 0.9750 -Validation Accuracy: 0.6742
# Epoch 75, CIFAR-10 Batch 4:  Cost :0.29051, Accuracy on Training 0.9250 -Validation Accuracy: 0.6548
# Epoch 75, CIFAR-10 Batch 5:  Cost :0.26046, Accuracy on Training 0.9750 -Validation Accuracy: 0.6676
# Epoch 76, CIFAR-10 Batch 1:  Cost :0.25902, Accuracy on Training 0.9500 -Validation Accuracy: 0.6666
# Epoch 76, CIFAR-10 Batch 2:  Cost :0.32409, Accuracy on Training 0.8500 -Validation Accuracy: 0.6586
# Epoch 76, CIFAR-10 Batch 3:  Cost :0.22160, Accuracy on Training 0.9750 -Validation Accuracy: 0.6652
# Epoch 76, CIFAR-10 Batch 4:  Cost :0.27164, Accuracy on Training 0.9250 -Validation Accuracy: 0.6688
# Epoch 76, CIFAR-10 Batch 5:  Cost :0.25444, Accuracy on Training 0.9750 -Validation Accuracy: 0.6548
# Epoch 77, CIFAR-10 Batch 1:  Cost :0.26114, Accuracy on Training 0.9500 -Validation Accuracy: 0.6676
# Epoch 77, CIFAR-10 Batch 2:  Cost :0.28205, Accuracy on Training 0.9000 -Validation Accuracy: 0.6674
# Epoch 77, CIFAR-10 Batch 3:  Cost :0.21884, Accuracy on Training 0.9750 -Validation Accuracy: 0.6652
# Epoch 77, CIFAR-10 Batch 4:  Cost :0.32808, Accuracy on Training 0.9250 -Validation Accuracy: 0.6526
# Epoch 77, CIFAR-10 Batch 5:  Cost :0.26426, Accuracy on Training 0.9750 -Validation Accuracy: 0.6500
# Epoch 78, CIFAR-10 Batch 1:  Cost :0.27637, Accuracy on Training 0.9500 -Validation Accuracy: 0.6568
# Epoch 78, CIFAR-10 Batch 2:  Cost :0.28431, Accuracy on Training 0.9250 -Validation Accuracy: 0.6636
# Epoch 78, CIFAR-10 Batch 3:  Cost :0.20972, Accuracy on Training 0.9500 -Validation Accuracy: 0.6690
# Epoch 78, CIFAR-10 Batch 4:  Cost :0.35446, Accuracy on Training 0.9500 -Validation Accuracy: 0.6544
# Epoch 78, CIFAR-10 Batch 5:  Cost :0.24584, Accuracy on Training 0.9750 -Validation Accuracy: 0.6676
# Epoch 79, CIFAR-10 Batch 1:  Cost :0.27669, Accuracy on Training 0.9500 -Validation Accuracy: 0.6658
# Epoch 79, CIFAR-10 Batch 2:  Cost :0.30559, Accuracy on Training 0.9000 -Validation Accuracy: 0.6612
# Epoch 79, CIFAR-10 Batch 3:  Cost :0.21177, Accuracy on Training 0.9750 -Validation Accuracy: 0.6680
# Epoch 79, CIFAR-10 Batch 4:  Cost :0.25790, Accuracy on Training 0.9500 -Validation Accuracy: 0.6554
# Epoch 79, CIFAR-10 Batch 5:  Cost :0.24561, Accuracy on Training 0.9750 -Validation Accuracy: 0.6676
# Epoch 80, CIFAR-10 Batch 1:  Cost :0.27098, Accuracy on Training 0.9250 -Validation Accuracy: 0.6730
# Epoch 80, CIFAR-10 Batch 2:  Cost :0.30997, Accuracy on Training 0.8500 -Validation Accuracy: 0.6510
# Epoch 80, CIFAR-10 Batch 3:  Cost :0.21222, Accuracy on Training 0.9750 -Validation Accuracy: 0.6626
# Epoch 80, CIFAR-10 Batch 4:  Cost :0.28638, Accuracy on Training 0.9500 -Validation Accuracy: 0.6404
# Epoch 80, CIFAR-10 Batch 5:  Cost :0.22243, Accuracy on Training 0.9750 -Validation Accuracy: 0.6564
# Epoch 81, CIFAR-10 Batch 1:  Cost :0.24412, Accuracy on Training 0.9500 -Validation Accuracy: 0.6692
# Epoch 81, CIFAR-10 Batch 2:  Cost :0.29487, Accuracy on Training 0.8750 -Validation Accuracy: 0.6694
# Epoch 81, CIFAR-10 Batch 3:  Cost :0.21260, Accuracy on Training 0.9750 -Validation Accuracy: 0.6624
# Epoch 81, CIFAR-10 Batch 4:  Cost :0.24188, Accuracy on Training 0.9500 -Validation Accuracy: 0.6522
# Epoch 81, CIFAR-10 Batch 5:  Cost :0.22873, Accuracy on Training 0.9750 -Validation Accuracy: 0.6506
# Epoch 82, CIFAR-10 Batch 1:  Cost :0.25884, Accuracy on Training 0.9500 -Validation Accuracy: 0.6624
# Epoch 82, CIFAR-10 Batch 2:  Cost :0.28495, Accuracy on Training 0.9250 -Validation Accuracy: 0.6690
# Epoch 82, CIFAR-10 Batch 3:  Cost :0.18794, Accuracy on Training 1.0000 -Validation Accuracy: 0.6654
# Epoch 82, CIFAR-10 Batch 4:  Cost :0.26546, Accuracy on Training 0.9500 -Validation Accuracy: 0.6470
# Epoch 82, CIFAR-10 Batch 5:  Cost :0.23326, Accuracy on Training 0.9750 -Validation Accuracy: 0.6574
# Epoch 83, CIFAR-10 Batch 1:  Cost :0.24119, Accuracy on Training 0.9750 -Validation Accuracy: 0.6632
# Epoch 83, CIFAR-10 Batch 2:  Cost :0.30588, Accuracy on Training 0.9000 -Validation Accuracy: 0.6570
# Epoch 83, CIFAR-10 Batch 3:  Cost :0.19295, Accuracy on Training 0.9750 -Validation Accuracy: 0.6674
# Epoch 83, CIFAR-10 Batch 4:  Cost :0.30867, Accuracy on Training 0.9500 -Validation Accuracy: 0.6486
# Epoch 83, CIFAR-10 Batch 5:  Cost :0.24693, Accuracy on Training 0.9750 -Validation Accuracy: 0.6658
# Epoch 84, CIFAR-10 Batch 1:  Cost :0.28211, Accuracy on Training 0.9250 -Validation Accuracy: 0.6660
# Epoch 84, CIFAR-10 Batch 2:  Cost :0.27568, Accuracy on Training 0.9250 -Validation Accuracy: 0.6626
# Epoch 84, CIFAR-10 Batch 3:  Cost :0.18448, Accuracy on Training 1.0000 -Validation Accuracy: 0.6692
# Epoch 84, CIFAR-10 Batch 4:  Cost :0.25131, Accuracy on Training 0.9500 -Validation Accuracy: 0.6478
# Epoch 84, CIFAR-10 Batch 5:  Cost :0.23748, Accuracy on Training 0.9750 -Validation Accuracy: 0.6648
# Epoch 85, CIFAR-10 Batch 1:  Cost :0.25611, Accuracy on Training 0.9500 -Validation Accuracy: 0.6584
# Epoch 85, CIFAR-10 Batch 2:  Cost :0.27273, Accuracy on Training 0.9500 -Validation Accuracy: 0.6686
# Epoch 85, CIFAR-10 Batch 3:  Cost :0.18040, Accuracy on Training 1.0000 -Validation Accuracy: 0.6724
# Epoch 85, CIFAR-10 Batch 4:  Cost :0.26854, Accuracy on Training 0.9250 -Validation Accuracy: 0.6506
# Epoch 85, CIFAR-10 Batch 5:  Cost :0.25273, Accuracy on Training 0.9750 -Validation Accuracy: 0.6674
# Epoch 86, CIFAR-10 Batch 1:  Cost :0.27168, Accuracy on Training 0.9500 -Validation Accuracy: 0.6710
# Epoch 86, CIFAR-10 Batch 2:  Cost :0.27340, Accuracy on Training 0.9250 -Validation Accuracy: 0.6684
# Epoch 86, CIFAR-10 Batch 3:  Cost :0.18909, Accuracy on Training 1.0000 -Validation Accuracy: 0.6626
# Epoch 86, CIFAR-10 Batch 4:  Cost :0.27580, Accuracy on Training 0.9250 -Validation Accuracy: 0.6486
# Epoch 86, CIFAR-10 Batch 5:  Cost :0.26042, Accuracy on Training 0.9750 -Validation Accuracy: 0.6614
# Epoch 87, CIFAR-10 Batch 1:  Cost :0.26469, Accuracy on Training 0.9500 -Validation Accuracy: 0.6622
# Epoch 87, CIFAR-10 Batch 2:  Cost :0.27125, Accuracy on Training 0.9000 -Validation Accuracy: 0.6666
# Epoch 87, CIFAR-10 Batch 3:  Cost :0.21196, Accuracy on Training 0.9750 -Validation Accuracy: 0.6616
# Epoch 87, CIFAR-10 Batch 4:  Cost :0.25554, Accuracy on Training 0.9250 -Validation Accuracy: 0.6492
# Epoch 87, CIFAR-10 Batch 5:  Cost :0.23784, Accuracy on Training 0.9750 -Validation Accuracy: 0.6644
# Epoch 88, CIFAR-10 Batch 1:  Cost :0.24310, Accuracy on Training 0.9500 -Validation Accuracy: 0.6660
# Epoch 88, CIFAR-10 Batch 2:  Cost :0.27502, Accuracy on Training 0.9000 -Validation Accuracy: 0.6612
# Epoch 88, CIFAR-10 Batch 3:  Cost :0.19134, Accuracy on Training 0.9750 -Validation Accuracy: 0.6672
# Epoch 88, CIFAR-10 Batch 4:  Cost :0.25726, Accuracy on Training 0.9500 -Validation Accuracy: 0.6526
# Epoch 88, CIFAR-10 Batch 5:  Cost :0.22141, Accuracy on Training 0.9750 -Validation Accuracy: 0.6632
# Epoch 89, CIFAR-10 Batch 1:  Cost :0.24945, Accuracy on Training 0.9500 -Validation Accuracy: 0.6686
# Epoch 89, CIFAR-10 Batch 2:  Cost :0.25977, Accuracy on Training 0.9000 -Validation Accuracy: 0.6554
# Epoch 89, CIFAR-10 Batch 3:  Cost :0.18497, Accuracy on Training 0.9750 -Validation Accuracy: 0.6694
# Epoch 89, CIFAR-10 Batch 4:  Cost :0.25510, Accuracy on Training 0.9500 -Validation Accuracy: 0.6534
# Epoch 89, CIFAR-10 Batch 5:  Cost :0.22844, Accuracy on Training 0.9750 -Validation Accuracy: 0.6666
# Epoch 90, CIFAR-10 Batch 1:  Cost :0.26023, Accuracy on Training 0.9500 -Validation Accuracy: 0.6628
# Epoch 90, CIFAR-10 Batch 2:  Cost :0.25417, Accuracy on Training 0.9250 -Validation Accuracy: 0.6636
# Epoch 90, CIFAR-10 Batch 3:  Cost :0.17874, Accuracy on Training 0.9500 -Validation Accuracy: 0.6634
# Epoch 90, CIFAR-10 Batch 4:  Cost :0.26593, Accuracy on Training 0.9500 -Validation Accuracy: 0.6546
# Epoch 90, CIFAR-10 Batch 5:  Cost :0.24914, Accuracy on Training 0.9750 -Validation Accuracy: 0.6614
# Epoch 91, CIFAR-10 Batch 1:  Cost :0.23453, Accuracy on Training 0.9500 -Validation Accuracy: 0.6632
# Epoch 91, CIFAR-10 Batch 2:  Cost :0.32780, Accuracy on Training 0.9000 -Validation Accuracy: 0.6590
# Epoch 91, CIFAR-10 Batch 3:  Cost :0.17198, Accuracy on Training 0.9750 -Validation Accuracy: 0.6638
# Epoch 91, CIFAR-10 Batch 4:  Cost :0.25299, Accuracy on Training 0.9500 -Validation Accuracy: 0.6598
# Epoch 91, CIFAR-10 Batch 5:  Cost :0.21529, Accuracy on Training 0.9750 -Validation Accuracy: 0.6612
# Epoch 92, CIFAR-10 Batch 1:  Cost :0.25063, Accuracy on Training 0.9500 -Validation Accuracy: 0.6622
# Epoch 92, CIFAR-10 Batch 2:  Cost :0.25968, Accuracy on Training 0.9250 -Validation Accuracy: 0.6742
# Epoch 92, CIFAR-10 Batch 3:  Cost :0.16802, Accuracy on Training 0.9750 -Validation Accuracy: 0.6654
# Epoch 92, CIFAR-10 Batch 4:  Cost :0.23950, Accuracy on Training 0.9500 -Validation Accuracy: 0.6552
# Epoch 92, CIFAR-10 Batch 5:  Cost :0.22961, Accuracy on Training 0.9500 -Validation Accuracy: 0.6640
# Epoch 93, CIFAR-10 Batch 1:  Cost :0.24531, Accuracy on Training 0.9500 -Validation Accuracy: 0.6660
# Epoch 93, CIFAR-10 Batch 2:  Cost :0.29969, Accuracy on Training 0.9250 -Validation Accuracy: 0.6652
# Epoch 93, CIFAR-10 Batch 3:  Cost :0.16675, Accuracy on Training 1.0000 -Validation Accuracy: 0.6626
# Epoch 93, CIFAR-10 Batch 4:  Cost :0.22730, Accuracy on Training 0.9500 -Validation Accuracy: 0.6706
# Epoch 93, CIFAR-10 Batch 5:  Cost :0.22394, Accuracy on Training 0.9750 -Validation Accuracy: 0.6586
# Epoch 94, CIFAR-10 Batch 1:  Cost :0.23397, Accuracy on Training 0.9250 -Validation Accuracy: 0.6736
# Epoch 94, CIFAR-10 Batch 2:  Cost :0.26297, Accuracy on Training 0.9000 -Validation Accuracy: 0.6630
# Epoch 94, CIFAR-10 Batch 3:  Cost :0.17889, Accuracy on Training 0.9750 -Validation Accuracy: 0.6704
# Epoch 94, CIFAR-10 Batch 4:  Cost :0.23053, Accuracy on Training 0.9500 -Validation Accuracy: 0.6624
# Epoch 94, CIFAR-10 Batch 5:  Cost :0.19750, Accuracy on Training 0.9750 -Validation Accuracy: 0.6690
# Epoch 95, CIFAR-10 Batch 1:  Cost :0.23914, Accuracy on Training 0.9500 -Validation Accuracy: 0.6592
# Epoch 95, CIFAR-10 Batch 2:  Cost :0.30683, Accuracy on Training 0.9000 -Validation Accuracy: 0.6688
# Epoch 95, CIFAR-10 Batch 3:  Cost :0.16049, Accuracy on Training 0.9750 -Validation Accuracy: 0.6804
# Epoch 95, CIFAR-10 Batch 4:  Cost :0.25832, Accuracy on Training 0.9500 -Validation Accuracy: 0.6674
# Epoch 95, CIFAR-10 Batch 5:  Cost :0.21193, Accuracy on Training 0.9750 -Validation Accuracy: 0.6680
# Epoch 96, CIFAR-10 Batch 1:  Cost :0.24442, Accuracy on Training 0.9250 -Validation Accuracy: 0.6656
# Epoch 96, CIFAR-10 Batch 2:  Cost :0.24595, Accuracy on Training 0.9250 -Validation Accuracy: 0.6576
# Epoch 96, CIFAR-10 Batch 3:  Cost :0.15803, Accuracy on Training 0.9750 -Validation Accuracy: 0.6766
# Epoch 96, CIFAR-10 Batch 4:  Cost :0.21936, Accuracy on Training 0.9500 -Validation Accuracy: 0.6598
# Epoch 96, CIFAR-10 Batch 5:  Cost :0.19703, Accuracy on Training 0.9750 -Validation Accuracy: 0.6682
# Epoch 97, CIFAR-10 Batch 1:  Cost :0.22520, Accuracy on Training 0.9500 -Validation Accuracy: 0.6644
# Epoch 97, CIFAR-10 Batch 2:  Cost :0.26006, Accuracy on Training 0.9000 -Validation Accuracy: 0.6632
# Epoch 97, CIFAR-10 Batch 3:  Cost :0.16644, Accuracy on Training 0.9500 -Validation Accuracy: 0.6636
# Epoch 97, CIFAR-10 Batch 4:  Cost :0.21632, Accuracy on Training 0.9500 -Validation Accuracy: 0.6664
# Epoch 97, CIFAR-10 Batch 5:  Cost :0.26212, Accuracy on Training 0.9500 -Validation Accuracy: 0.6540
# Epoch 98, CIFAR-10 Batch 1:  Cost :0.20549, Accuracy on Training 0.9500 -Validation Accuracy: 0.6724
# Epoch 98, CIFAR-10 Batch 2:  Cost :0.26030, Accuracy on Training 0.9250 -Validation Accuracy: 0.6614
# Epoch 98, CIFAR-10 Batch 3:  Cost :0.17265, Accuracy on Training 0.9750 -Validation Accuracy: 0.6726
# Epoch 98, CIFAR-10 Batch 4:  Cost :0.22507, Accuracy on Training 0.9500 -Validation Accuracy: 0.6588
# Epoch 98, CIFAR-10 Batch 5:  Cost :0.19356, Accuracy on Training 0.9750 -Validation Accuracy: 0.6708
# Epoch 99, CIFAR-10 Batch 1:  Cost :0.19242, Accuracy on Training 0.9750 -Validation Accuracy: 0.6650
# Epoch 99, CIFAR-10 Batch 2:  Cost :0.24200, Accuracy on Training 0.9250 -Validation Accuracy: 0.6654
# Epoch 99, CIFAR-10 Batch 3:  Cost :0.15515, Accuracy on Training 0.9750 -Validation Accuracy: 0.6700
# Epoch 99, CIFAR-10 Batch 4:  Cost :0.22372, Accuracy on Training 0.9500 -Validation Accuracy: 0.6540
# Epoch 99, CIFAR-10 Batch 5:  Cost :0.18974, Accuracy on Training 0.9750 -Validation Accuracy: 0.6664
# Epoch 100, CIFAR-10 Batch 1:  Cost :0.20936, Accuracy on Training 0.9500 -Validation Accuracy: 0.6694
# Epoch 100, CIFAR-10 Batch 2:  Cost :0.24603, Accuracy on Training 0.9250 -Validation Accuracy: 0.6664
# Epoch 100, CIFAR-10 Batch 3:  Cost :0.17093, Accuracy on Training 0.9500 -Validation Accuracy: 0.6664
# Epoch 100, CIFAR-10 Batch 4:  Cost :0.23617, Accuracy on Training 0.9500 -Validation Accuracy: 0.6612
# Epoch 100, CIFAR-10 Batch 5:  Cost :0.19613, Accuracy on Training 0.9750 -Validation Accuracy: 0.6674

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6736328125

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
